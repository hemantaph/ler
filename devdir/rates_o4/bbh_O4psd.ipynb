# %%
import numpy as np
import matplotlib.pyplot as plt
from ler.rates import LeR
from ler.utils import get_param_from_json
# Out:
# Setting multiprocessing start method to 'fork'

# %%
import ler
import gwsnr
print(f"ler version: {ler.__version__}")
print(f"gwsnr version: {gwsnr.__version__}")
# Out:
# ler version: 0.4.0
# gwsnr version: 0.3.2

# %% [markdown]
# ## MEDIAN

# %%
ler = LeR(npool=8,
          verbose=False, 
          event_type='BBH',
          source_priors= {'merger_rate_density': 'merger_rate_density_bbh_popI_II_oguri2018'},
          source_priors_params= {'merger_rate_density': {'R0': 2.39e-08, 'b2': 1.6, 'b3': 2.0, 'b4': 30}},
          psds={'L1':'o4_psd.txt', 'H1':'o4_psd.txt'},
          snr_type="interpolation",
          )
# Out:
# interpolation for each mass_ratios: 100%|███████████████████████████| 50/50 [01:11<00:00,  1.42s/it]

# %% [markdown]
# ## Unlensed

# %%
# snr_cut=8.0
ler.selecting_n_unlensed_detectable_events(size=20000, batch_size=200000,snr_threshold=8.0, output_jsonfile='n_unlensed_detectable_bbh_O4psd_median.json', meta_data_file='n_unlensed_detectable_bbh_meta_O4psd_median.json', resume=True);
# Out:
# collected number of detectable events =  10000
# given detectability_condition == 'step_function'
# collected number of detectable events =  10278
# total number of events =  7386219.0
# total rate (yr^-1): 144.05317948279597
# given detectability_condition == 'step_function'
# collected number of detectable events =  10544
# total number of events =  7586219.0
# total rate (yr^-1): 143.8853033115929
# given detectability_condition == 'step_function'
# collected number of detectable events =  10821
# total number of events =  7786219.0
# total rate (yr^-1): 143.8723036383584
# given detectability_condition == 'step_function'
# collected number of detectable events =  11098
# total number of events =  7986219.0
# total rate (yr^-1): 143.8599550703958
# given detectability_condition == 'step_function'
# collected number of detectable events =  11363
# total number of events =  8186219.0
# total rate (yr^-1): 143.69645792797235
# given detectability_condition == 'step_function'
# collected number of detectable events =  11648
# total number of events =  8386219.0
# total rate (yr^-1): 143.787647288378
# given detectability_condition == 'step_function'
# collected number of detectable events =  11919
# total number of events =  8586219.0
# total rate (yr^-1): 143.70579234410982
# given detectability_condition == 'step_function'
# collected number of detectable events =  12202
# total number of events =  8786219.0
# total rate (yr^-1): 143.76905291960816
# given detectability_condition == 'step_function'
# collected number of detectable events =  12457
# total number of events =  8986219.0
# total rate (yr^-1): 143.5069324494031
# given detectability_condition == 'step_function'
# collected number of detectable events =  12752
# total number of events =  9186219.0
# total rate (yr^-1): 143.707000399949
# given detectability_condition == 'step_function'
# collected number of detectable events =  13036
# total number of events =  9386219.0
# total rate (yr^-1): 143.77722064047734
# given detectability_condition == 'step_function'
# collected number of detectable events =  13331
# total number of events =  9586219.0
# total rate (yr^-1): 143.96330134345115
# given detectability_condition == 'step_function'
# collected number of detectable events =  13636
# total number of events =  9786219.0
# total rate (yr^-1): 144.24756058553803
# given detectability_condition == 'step_function'
# collected number of detectable events =  13906
# total number of events =  9986219.0
# total rate (yr^-1): 144.1576036124578
# given detectability_condition == 'step_function'
# collected number of detectable events =  14163
# total number of events =  10186219.0
# total rate (yr^-1): 143.9390596860995
# given detectability_condition == 'step_function'
# collected number of detectable events =  14422
# total number of events =  10386219.0
# total rate (yr^-1): 143.74886711298666
# given detectability_condition == 'step_function'
# collected number of detectable events =  14705
# total number of events =  10586219.0
# total rate (yr^-1): 143.8005575528518
# given detectability_condition == 'step_function'
# collected number of detectable events =  14994
# total number of events =  10786219.0
# total rate (yr^-1): 143.90791728736824
# given detectability_condition == 'step_function'
# collected number of detectable events =  15291
# total number of events =  10986219.0
# total rate (yr^-1): 144.08675195598468
# given detectability_condition == 'step_function'
# collected number of detectable events =  15564
# total number of events =  11186219.0
# total rate (yr^-1): 144.03708373314453
# given detectability_condition == 'step_function'
# collected number of detectable events =  15842
# total number of events =  11386219.0
# total rate (yr^-1): 144.03462009789936
# given detectability_condition == 'step_function'
# collected number of detectable events =  16113
# total number of events =  11586219.0
# total rate (yr^-1): 143.96969649861097
# given detectability_condition == 'step_function'
# collected number of detectable events =  16390
# total number of events =  11786219.0
# total rate (yr^-1): 143.95967658127057
# given detectability_condition == 'step_function'
# collected number of detectable events =  16664
# total number of events =  11986219.0
# total rate (yr^-1): 143.9240805650053
# given detectability_condition == 'step_function'
# collected number of detectable events =  16940
# total number of events =  12186219.0
# total rate (yr^-1): 143.90664310962887
# given detectability_condition == 'step_function'
# collected number of detectable events =  17227
# total number of events =  12386219.0
# total rate (yr^-1): 143.98170578240342
# given detectability_condition == 'step_function'
# collected number of detectable events =  17523
# total number of events =  12586219.0
# total rate (yr^-1): 144.12840879453125
# given detectability_condition == 'step_function'
# collected number of detectable events =  17794
# total number of events =  12786219.0
# total rate (yr^-1): 144.0681113149597
# given detectability_condition == 'step_function'
# collected number of detectable events =  18069
# total number of events =  12986219.0
# total rate (yr^-1): 144.04155811293717
# given detectability_condition == 'step_function'
# collected number of detectable events =  18336
# total number of events =  13186219.0
# total rate (yr^-1): 143.95300367371155
# given detectability_condition == 'step_function'
# collected number of detectable events =  18618
# total number of events =  13386219.0
# total rate (yr^-1): 143.98309851287928
# given detectability_condition == 'step_function'
# collected number of detectable events =  18881
# total number of events =  13586219.0
# total rate (yr^-1): 143.86753303469442
# given detectability_condition == 'step_function'
# collected number of detectable events =  19174
# total number of events =  13786219.0
# total rate (yr^-1): 143.98059536877798
# given detectability_condition == 'step_function'
# collected number of detectable events =  19431
# total number of events =  13986219.0
# total rate (yr^-1): 143.82396013760726
# given detectability_condition == 'step_function'
# collected number of detectable events =  19725
# total number of events =  14186219.0
# total rate (yr^-1): 143.94174624920964
# given detectability_condition == 'step_function'
# collected number of detectable events =  19981
# total number of events =  14386219.0
# total rate (yr^-1): 143.78281027590347
# given detectability_condition == 'step_function'
# collected number of detectable events =  20255
# total number of events =  14586219.0
# total rate (yr^-1): 143.75598438048743
# stored detectable unlensed params in ./ler_data/n_unlensed_detectable_bbh_O4psd_median.json
# stored meta data in ./ler_data/n_unlensed_detectable_bbh_meta_O4psd_median.json
#
#  trmming final result to size=20000
# collected number of detectable events =  20000
# total number of events =  14402586.0
# total unlensed event rate (yr^-1): 143.7559846613721

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_unlensed_detectable_bbh_meta_O4psd_median.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1e7)[0]
# take average 
rate_unlensed_median = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_unlensed_median)
# Out:
# Rate (per year) = 143.940150873906

# %% [markdown]
# ## Lensed

# %%
# snr_cut=8.0
# time will take long time sample
ler.selecting_n_lensed_detectable_events(size=2000, batch_size=200000,snr_threshold=8.0, num_img=2, output_jsonfile='n_lensed_detectable_bbh_O4psd_median.json', meta_data_file='n_lensed_detectable_bbh_meta_O4psd_median.json', resume=True);
# Out:
# collected number of detectable events =  1000
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4510.84it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 88.84it/s]
# given detectability_condition == step_function
# collected number of detectable events =  1273
# total number of events =  889655.0
# total rate (yr^-1): 0.324745690621992
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4467.19it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 72.89it/s]
# given detectability_condition == step_function
# collected number of detectable events =  1544
# total number of events =  1089655.0
# total rate (yr^-1): 0.32158434364435634
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4496.62it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 78.14it/s]
# given detectability_condition == step_function
# collected number of detectable events =  1825
# total number of events =  1289655.0
# total rate (yr^-1): 0.32116332054552604
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4495.73it/s]
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.89it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2110
# total number of events =  1489655.0
# total rate (yr^-1): 0.32146476182930694
# storing detectable lensed params in ./ler_data/n_lensed_detectable_bbh_O4psd_median.json
# storing meta data in ./ler_data/n_lensed_detectable_bbh_meta_O4psd_median.json
#
#  trmming final result to size=2000
# collected number of detectable events =  2000
# total number of events =  1411995.0
# total lensed event rate (yr^-1): 0.3214648211738034

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_lensed_detectable_bbh_meta_O4psd_median.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1e6)[0]
# take average 
rate_lensed_median = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_lensed_median)
# Out:
# Rate (per year) = 0.32140416178789527

# %%
rate_unlensed_median/rate_lensed_median, rate_unlensed_median, rate_lensed_median
# Out:
# (447.84781277629077, 143.940150873906, 0.32140416178789527)

# %% [markdown]
# ## LOW

# %%
ler = LeR(npool=8,
          verbose=False, 
          event_type='BBH',
          source_priors= {'merger_rate_density': 'merger_rate_density_bbh_popI_II_oguri2018'},
          source_priors_params= {'merger_rate_density': {'R0': (2.39-0.86)*1e-08, 'b2': 1.6, 'b3': 2.0, 'b4': 30}},
          psds={'L1':'o4_psd.txt', 'H1':'o4_psd.txt'},
          snr_type="interpolation",
          )

# %%
# snr_cut=8.0
ler.selecting_n_unlensed_detectable_events(size=20000, batch_size=200000,snr_threshold=8.0, output_jsonfile='n_unlensed_detectable_bbh_O4psd_low.json', meta_data_file='n_unlensed_detectable_bbh_meta_O4psd_low.json', resume=False);
# Out:
# removing ./ler_data/n_unlensed_detectable_bbh_O4psd_low.json and ./ler_data/n_unlensed_detectable_bbh_meta_O4psd_low.json if they exist
# collected number of detectable events =  0
# given detectability_condition == 'step_function'
# collected number of detectable events =  281
# total number of events =  200000
# total rate (yr^-1): 93.1121316681792
# given detectability_condition == 'step_function'
# collected number of detectable events =  540
# total number of events =  400000
# total rate (yr^-1): 89.46717277725404
# given detectability_condition == 'step_function'
# collected number of detectable events =  815
# total number of events =  600000
# total rate (yr^-1): 90.01943927587907
# given detectability_condition == 'step_function'
# collected number of detectable events =  1101
# total number of events =  800000
# total rate (yr^-1): 91.20681224792287
# given detectability_condition == 'step_function'
# collected number of detectable events =  1385
# total number of events =  1000000
# total rate (yr^-1): 91.78669207147914
# given detectability_condition == 'step_function'
# collected number of detectable events =  1663
# total number of events =  1200000
# total rate (yr^-1): 91.84191872134164
# given detectability_condition == 'step_function'
# collected number of detectable events =  1890
# total number of events =  1400000
# total rate (yr^-1): 89.46717277725404
# given detectability_condition == 'step_function'
# collected number of detectable events =  2159
# total number of events =  1600000
# total rate (yr^-1): 89.42575278985717
# given detectability_condition == 'step_function'
# collected number of detectable events =  2434
# total number of events =  1800000
# total rate (yr^-1): 89.61444384355404
# given detectability_condition == 'step_function'
# collected number of detectable events =  2734
# total number of events =  2000000
# total rate (yr^-1): 90.59379643444909
# given detectability_condition == 'step_function'
# collected number of detectable events =  3019
# total number of events =  2200000
# total rate (yr^-1): 90.94323050994274
# given detectability_condition == 'step_function'
# collected number of detectable events =  3315
# total number of events =  2400000
# total rate (yr^-1): 91.53817214709787
# given detectability_condition == 'step_function'
# collected number of detectable events =  3604
# total number of events =  2600000
# total rate (yr^-1): 91.86315974051952
# given detectability_condition == 'step_function'
# collected number of detectable events =  3885
# total number of events =  2800000
# total rate (yr^-1): 91.95237202106664
# given detectability_condition == 'step_function'
# collected number of detectable events =  4137
# total number of events =  3000000
# total rate (yr^-1): 91.38906019246912
# given detectability_condition == 'step_function'
# collected number of detectable events =  4418
# total number of events =  3200000
# total rate (yr^-1): 91.496752159701
# given detectability_condition == 'step_function'
# collected number of detectable events =  4696
# total number of events =  3400000
# total rate (yr^-1): 91.53329920740413
# given detectability_condition == 'step_function'
# collected number of detectable events =  4969
# total number of events =  3600000
# total rate (yr^-1): 91.47374105559162
# given detectability_condition == 'step_function'
# collected number of detectable events =  5238
# total number of events =  3800000
# total rate (yr^-1): 91.3506922041436
# given detectability_condition == 'step_function'
# collected number of detectable events =  5509
# total number of events =  4000000
# total rate (yr^-1): 91.27308422775788
# given detectability_condition == 'step_function'
# collected number of detectable events =  5781
# total number of events =  4200000
# total rate (yr^-1): 91.21864653003625
# given detectability_condition == 'step_function'
# collected number of detectable events =  6070
# total number of events =  4400000
# total rate (yr^-1): 91.42520854510639
# given detectability_condition == 'step_function'
# collected number of detectable events =  6347
# total number of events =  4600000
# total rate (yr^-1): 91.44092522016608
# given detectability_condition == 'step_function'
# collected number of detectable events =  6649
# total number of events =  4800000
# total rate (yr^-1): 91.80049873394476
# given detectability_condition == 'step_function'
# collected number of detectable events =  6929
# total number of events =  5000000
# total rate (yr^-1): 91.83970965534715
# given detectability_condition == 'step_function'
# collected number of detectable events =  7246
# total number of events =  5200000
# total rate (yr^-1): 92.34745497777531
# given detectability_condition == 'step_function'
# collected number of detectable events =  7527
# total number of events =  5400000
# total rate (yr^-1): 92.37577633667917
# given detectability_condition == 'step_function'
# collected number of detectable events =  7793
# total number of events =  5600000
# total rate (yr^-1): 92.2245605096747
# given detectability_condition == 'step_function'
# collected number of detectable events =  8094
# total number of events =  5800000
# total rate (yr^-1): 92.48369048008865
# given detectability_condition == 'step_function'
# collected number of detectable events =  8357
# total number of events =  6000000
# total rate (yr^-1): 92.30582258018667
# given detectability_condition == 'step_function'
# collected number of detectable events =  8645
# total number of events =  6200000
# total rate (yr^-1): 92.40665575380658
# given detectability_condition == 'step_function'
# collected number of detectable events =  8911
# total number of events =  6400000
# total rate (yr^-1): 92.27337692339243
# given detectability_condition == 'step_function'
# collected number of detectable events =  9155
# total number of events =  6600000
# total rate (yr^-1): 91.92726899840187
# given detectability_condition == 'step_function'
# collected number of detectable events =  9410
# total number of events =  6800000
# total rate (yr^-1): 91.70872503637914
# given detectability_condition == 'step_function'
# collected number of detectable events =  9694
# total number of events =  7000000
# total rate (yr^-1): 91.77722464578844
# given detectability_condition == 'step_function'
# collected number of detectable events =  9975
# total number of events =  7200000
# total rate (yr^-1): 91.81430539641039
# given detectability_condition == 'step_function'
# collected number of detectable events =  10236
# total number of events =  7400000
# total rate (yr^-1): 91.67026832312034
# given detectability_condition == 'step_function'
# collected number of detectable events =  10497
# total number of events =  7600000
# total rate (yr^-1): 91.53381214842453
# given detectability_condition == 'step_function'
# collected number of detectable events =  10786
# total number of events =  7800000
# total rate (yr^-1): 91.64225314106952
# given detectability_condition == 'step_function'
# collected number of detectable events =  11048
# total number of events =  8000000
# total rate (yr^-1): 91.52160415213913
# given detectability_condition == 'step_function'
# collected number of detectable events =  11318
# total number of events =  8200000
# total rate (yr^-1): 91.47149606982485
# given detectability_condition == 'step_function'
# collected number of detectable events =  11612
# total number of events =  8400000
# total rate (yr^-1): 91.6131226004827
# given detectability_condition == 'step_function'
# collected number of detectable events =  11890
# total number of events =  8600000
# total rate (yr^-1): 91.62486514397506
# given detectability_condition == 'step_function'
# collected number of detectable events =  12184
# total number of events =  8800000
# total rate (yr^-1): 91.75656844428141
# given detectability_condition == 'step_function'
# collected number of detectable events =  12457
# total number of events =  9000000
# total rate (yr^-1): 91.72778364495913
# given detectability_condition == 'step_function'
# collected number of detectable events =  12731
# total number of events =  9200000
# total rate (yr^-1): 91.70745383471989
# given detectability_condition == 'step_function'
# collected number of detectable events =  13019
# total number of events =  9400000
# total rate (yr^-1): 91.78669207147914
# given detectability_condition == 'step_function'
# collected number of detectable events =  13301
# total number of events =  9600000
# total rate (yr^-1): 91.82120872764321
# given detectability_condition == 'step_function'
# collected number of detectable events =  13571
# total number of events =  9800000
# total rate (yr^-1): 91.77316717763526
# given detectability_condition == 'step_function'
# collected number of detectable events =  13823
# total number of events =  10000000
# total rate (yr^-1): 91.60775772592463
# given detectability_condition == 'step_function'
# collected number of detectable events =  14087
# total number of events =  10200000
# total rate (yr^-1): 91.52680195447913
# given detectability_condition == 'step_function'
# collected number of detectable events =  14374
# total number of events =  10400000
# total rate (yr^-1): 91.59552289887817
# given detectability_condition == 'step_function'
# collected number of detectable events =  14651
# total number of events =  10600000
# total rate (yr^-1): 91.59912986439893
# given detectability_condition == 'step_function'
# collected number of detectable events =  14911
# total number of events =  10800000
# total rate (yr^-1): 91.49828623330829
# given detectability_condition == 'step_function'
# collected number of detectable events =  15166
# total number of events =  11000000
# total rate (yr^-1): 91.37098601615048
# given detectability_condition == 'step_function'
# collected number of detectable events =  15435
# total number of events =  11200000
# total rate (yr^-1): 91.33107221011349
# given detectability_condition == 'step_function'
# collected number of detectable events =  15716
# total number of events =  11400000
# total rate (yr^-1): 91.36231886727255
# given detectability_condition == 'step_function'
# collected number of detectable events =  15976
# total number of events =  11600000
# total rate (yr^-1): 91.27251291758688
# given detectability_condition == 'step_function'
# collected number of detectable events =  16267
# total number of events =  11800000
# total rate (yr^-1): 91.3598555911859
# given detectability_condition == 'step_function'
# collected number of detectable events =  16524
# total number of events =  12000000
# total rate (yr^-1): 91.25651623279911
# given detectability_condition == 'step_function'
# collected number of detectable events =  16819
# total number of events =  12200000
# total rate (yr^-1): 91.36298597089468
# given detectability_condition == 'step_function'
# collected number of detectable events =  17079
# total number of events =  12400000
# total rate (yr^-1): 91.27896319371096
# given detectability_condition == 'step_function'
# collected number of detectable events =  17347
# total number of events =  12600000
# total rate (yr^-1): 91.2396852537934
# given detectability_condition == 'step_function'
# collected number of detectable events =  17613
# total number of events =  12800000
# total rate (yr^-1): 91.19127975264904
# given detectability_condition == 'step_function'
# collected number of detectable events =  17893
# total number of events =  13000000
# total rate (yr^-1): 91.21573347597757
# given detectability_condition == 'step_function'
# collected number of detectable events =  18171
# total number of events =  13200000
# total rate (yr^-1): 91.22940496832116
# given detectability_condition == 'step_function'
# collected number of detectable events =  18455
# total number of events =  13400000
# total rate (yr^-1): 91.27234237723734
# given detectability_condition == 'step_function'
# collected number of detectable events =  18730
# total number of events =  13600000
# total rate (yr^-1): 91.27016046394162
# given detectability_condition == 'step_function'
# collected number of detectable events =  19003
# total number of events =  13800000
# total rate (yr^-1): 91.25843715975086
# given detectability_condition == 'step_function'
# collected number of detectable events =  19283
# total number of events =  14000000
# total rate (yr^-1): 91.2801847970259
# given detectability_condition == 'step_function'
# collected number of detectable events =  19581
# total number of events =  14200000
# total rate (yr^-1): 91.38532655980237
# given detectability_condition == 'step_function'
# collected number of detectable events =  19869
# total number of events =  14400000
# total rate (yr^-1): 91.4415255098385
# given detectability_condition == 'step_function'
# collected number of detectable events =  20159
# total number of events =  14600000
# total rate (yr^-1): 91.50526311601543
# stored detectable unlensed params in ./ler_data/n_unlensed_detectable_bbh_O4psd_low.json
# stored meta data in ./ler_data/n_unlensed_detectable_bbh_meta_O4psd_low.json
#
#  trmming final result to size=20000
# collected number of detectable events =  20000
# total number of events =  14484845.0
# total unlensed event rate (yr^-1): 91.50526613850958

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_unlensed_detectable_bbh_meta_O4psd_low.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1.2e7)[0]
# take average 
rate_unlensed_low = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_unlensed_low)
# Out:
# Rate (per year) = 91.30240735549638

# %%
# snr_cut=8.0
# time will take long time sample
ler.selecting_n_lensed_detectable_events(size=10000, batch_size=200000,snr_threshold=8.0, num_img=2, output_jsonfile='n_lensed_detectable_bbh_O4psd_low.json', meta_data_file='n_lensed_detectable_bbh_meta_O4psd_low.json', resume=True)
# Out:
# collected number of detectable events =  1734
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4505.16it/s]
# 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 101.06it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2024
# total number of events =  1400000
# total rate (yr^-1): 0.21004513127541477
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4526.26it/s]
# 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 62.71it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2310
# total number of events =  1600000
# total rate (yr^-1): 0.20975974386879057
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4542.05it/s]
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.14it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2581
# total number of events =  1800000
# total rate (yr^-1): 0.20832704143351555
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4532.87it/s]
# 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 68.16it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2851
# total number of events =  2000000
# total rate (yr^-1): 0.2071082354181548
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4540.34it/s]
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.02it/s]
# given detectability_condition == step_function
# collected number of detectable events =  3164
# total number of events =  2200000
# total rate (yr^-1): 0.20895075312108724
#  20%|██████████▌                                           | 39127/200000 [00:08<00:36, 4456.08it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 # snr_cut=8.0
#       2 # time will take long time sample
# ----> 3 ler.selecting_n_lensed_detectable_events(size=10000, batch_size=200000,snr_threshold=8.0, num_img=2, output_jsonfile='n_lensed_detectable_bbh_O4psd_low.json', meta_data_file='n_lensed_detectable_bbh_meta_O4psd_low.json', resume=True)
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:2004, in LeR.selecting_n_lensed_detectable_events(self, size, batch_size, snr_threshold, pdet_threshold, num_img, combine_image_snr, snr_cut_for_combine_image_snr, resume, detectability_condition, output_jsonfile, meta_data_file, trim_to_size, nan_to_num, snr_recalculation, snr_threshold_recalculation)
#    2002 with contextlib.redirect_stdout(None):
#    2003     self.dict_buffer = None  # this is used to store the sampled lensed_param in batches when running the sampling_routine
# -> 2004     lensed_param = self.lensed_sampling_routine(
#    2005         size=self.batch_size, output_jsonfile=buffer_file, resume=False
#    2006     )  # Dimensions are (size, n_max_images)
#    2008 total_events_in_this_iteration = len(lensed_param["zs"])
#    2010 # Below code ensures that the snr is recalculated for the detectable events with inner product
#    2011 # The code is use when the snr is calculated with 'ann' method of `gwsnr`
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:1356, in LeR.lensed_sampling_routine(self, size, output_jsonfile, save_batch, resume)
#    1354 lensed_param_ = self.sample_lens_parameters(size=size)
#    1355 # now get (strongly lensed) image paramters along with lens parameters
# -> 1356 lensed_param_ = self.image_properties(lensed_param_)
#    1358 if len(lensed_param) == 0:  # if empty
#    1359         lensed_param = lensed_param_
#
# File ~/phd/mypackages/ler/ler/image_properties/image_properties.py:253, in ImageProperties.image_properties(self, lens_parameters)
#     249     raise ValueError("n_min_images should be greater than 1")
#     250 with Pool(processes=npool) as pool:
#     251     # call the same function with different data in parallel
#     252     # imap->retain order in the list, while map->doesn't
# --> 253     for result in tqdm(
#     254         pool.imap_unordered(solve_lens_equation_, input_arguments),
#     255         total=len(input_arguments),
#     256         ncols=100,
#     257         disable=False,
#     258     ):
#     259         # print(result)
#     260         (
#     261             x_source_i,
#     262             y_source_i,
#    (...)
#     270             iter_i,
#     271         ) = result
#     273         n_image_i = min(n_image_i, n_max_images)
#
# File ~/anaconda3/envs/ler/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/envs/ler/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_lensed_detectable_bbh_meta_O4psd_low.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1.5e6)[0]
# take average 
rate_lensed_low = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_lensed_low)
# Out:
# Rate (per year) = 0.20853644346038705

# %%
rate_unlensed_low/rate_lensed_low, rate_unlensed_low, rate_lensed_low
# Out:
# (437.82470747296463, 91.30240735549638, 0.20853644346038705)

# %% [markdown]
# ## HIGH

# %%
ler = LeR(npool=8,
          verbose=False, 
          event_type='BBH',
          source_priors= {'merger_rate_density': 'merger_rate_density_bbh_popI_II_oguri2018'},
          source_priors_params= {'merger_rate_density': {'R0': (2.39+1.49)*1e-08, 'b2': 1.6, 'b3': 2.0, 'b4': 30}},
          psds={'L1':'o4_psd.txt', 'H1':'o4_psd.txt'},
          snr_type="interpolation",
          )

# %%
# snr_cut=8.0
ler.selecting_n_unlensed_detectable_events(size=20000, batch_size=200000,snr_threshold=8.0, output_jsonfile='n_unlensed_detectable_bbh_O4psd_high.json', meta_data_file='n_unlensed_detectable_bbh_meta_O4psd_high.json', resume=True);
# Out:
# collected number of detectable events =  10000
# given detectability_condition == 'step_function'
# collected number of detectable events =  10303
# total number of events =  7395683.0
# total rate (yr^-1): 234.12923811432395
# given detectability_condition == 'step_function'
# collected number of detectable events =  10588
# total number of events =  7595683.0
# total rate (yr^-1): 234.27035787145934
# given detectability_condition == 'step_function'
# collected number of detectable events =  10833
# total number of events =  7795683.0
# total rate (yr^-1): 233.54190161719785
# given detectability_condition == 'step_function'
# collected number of detectable events =  11126
# total number of events =  7995683.0
# total rate (yr^-1): 233.85880593230672
# given detectability_condition == 'step_function'
# collected number of detectable events =  11401
# total number of events =  8195683.0
# total rate (yr^-1): 233.79113184340414
# given detectability_condition == 'step_function'
# collected number of detectable events =  11675
# total number of events =  8395683.0
# total rate (yr^-1): 233.70666428575115
# given detectability_condition == 'step_function'
# collected number of detectable events =  11953
# total number of events =  8595683.0
# total rate (yr^-1): 233.7043351836114
# given detectability_condition == 'step_function'
# collected number of detectable events =  12239
# total number of events =  8795683.0
# total rate (yr^-1): 233.85497087637563
# given detectability_condition == 'step_function'
# collected number of detectable events =  12516
# total number of events =  8995683.0
# total rate (yr^-1): 233.83076550837268
# given detectability_condition == 'step_function'
# collected number of detectable events =  12803
# total number of events =  9195683.0
# total rate (yr^-1): 233.99037518747403
# given detectability_condition == 'step_function'
# collected number of detectable events =  13065
# total number of events =  9395683.0
# total rate (yr^-1): 233.69601033772625
# given detectability_condition == 'step_function'
# collected number of detectable events =  13298
# total number of events =  9595683.0
# total rate (yr^-1): 232.90599967993737
# given detectability_condition == 'step_function'
# collected number of detectable events =  13570
# total number of events =  9795683.0
# total rate (yr^-1): 232.81736257760716
# given detectability_condition == 'step_function'
# collected number of detectable events =  13841
# total number of events =  9995683.0
# total rate (yr^-1): 232.71545900466876
# given detectability_condition == 'step_function'
# collected number of detectable events =  14127
# total number of events =  10195683.0
# total rate (yr^-1): 232.86480839478108
# given detectability_condition == 'step_function'
# collected number of detectable events =  14393
# total number of events =  10395683.0
# total rate (yr^-1): 232.68508029481936
# given detectability_condition == 'step_function'
# collected number of detectable events =  14651
# total number of events =  10595683.0
# total rate (yr^-1): 232.38524601904103
# given detectability_condition == 'step_function'
# collected number of detectable events =  14922
# total number of events =  10795683.0
# total rate (yr^-1): 232.29889923579938
# given detectability_condition == 'step_function'
# collected number of detectable events =  15191
# total number of events =  10995683.0
# total rate (yr^-1): 232.18512479408278
# given detectability_condition == 'step_function'
# collected number of detectable events =  15473
# total number of events =  11195683.0
# total rate (yr^-1): 232.2705627952575
# given detectability_condition == 'step_function'
# collected number of detectable events =  15740
# total number of events =  11395683.0
# total rate (yr^-1): 232.13178349103944
# given detectability_condition == 'step_function'
# collected number of detectable events =  16022
# total number of events =  11595683.0
# total rate (yr^-1): 232.2151942774428
# given detectability_condition == 'step_function'
# collected number of detectable events =  16294
# total number of events =  11795683.0
# total rate (yr^-1): 232.15329876228134
# given detectability_condition == 'step_function'
# collected number of detectable events =  16564
# total number of events =  11995683.0
# total rate (yr^-1): 232.06544671381909
# given detectability_condition == 'step_function'
# collected number of detectable events =  16830
# total number of events =  12195683.0
# total rate (yr^-1): 231.92535418950519
# given detectability_condition == 'step_function'
# collected number of detectable events =  17115
# total number of events =  12395683.0
# total rate (yr^-1): 232.04738681370193
# given detectability_condition == 'step_function'
# collected number of detectable events =  17400
# total number of events =  12595683.0
# total rate (yr^-1): 232.1655440585581
# given detectability_condition == 'step_function'
# collected number of detectable events =  17653
# total number of events =  12795683.0
# total rate (yr^-1): 231.85971020273894
# given detectability_condition == 'step_function'
# collected number of detectable events =  17939
# total number of events =  12995683.0
# total rate (yr^-1): 231.990051085801
# given detectability_condition == 'step_function'
# collected number of detectable events =  18192
# total number of events =  13195683.0
# total rate (yr^-1): 231.69614780885973
# given detectability_condition == 'step_function'
# collected number of detectable events =  18465
# total number of events =  13395683.0
# total rate (yr^-1): 231.66194064625444
# given detectability_condition == 'step_function'
# collected number of detectable events =  18747
# total number of events =  13595683.0
# total rate (yr^-1): 231.73999289319715
# given detectability_condition == 'step_function'
# collected number of detectable events =  19038
# total number of events =  13795683.0
# total rate (yr^-1): 231.92542217846147
# given detectability_condition == 'step_function'
# collected number of detectable events =  19320
# total number of events =  13995683.0
# total rate (yr^-1): 231.9974784904278
# given detectability_condition == 'step_function'
# collected number of detectable events =  19623
# total number of events =  14195683.0
# total rate (yr^-1): 232.3161228153889
# given detectability_condition == 'step_function'
# collected number of detectable events =  19887
# total number of events =  14395683.0
# total rate (yr^-1): 232.17060809484136
# given detectability_condition == 'step_function'
# collected number of detectable events =  20171
# total number of events =  14595683.0
# total rate (yr^-1): 232.25937164694602
# stored detectable unlensed params in ./ler_data/n_unlensed_detectable_bbh_O4psd_high.json
# stored meta data in ./ler_data/n_unlensed_detectable_bbh_meta_O4psd_high.json
#
#  trmming final result to size=20000
# collected number of detectable events =  20000
# total number of events =  14471948.0
# total unlensed event rate (yr^-1): 232.2593691740843

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_unlensed_detectable_bbh_meta_O4psd_high.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1.2e7)[0]
# take average 
rate_unlensed_high = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_unlensed_high)
# Out:
# Rate (per year) = 231.98116372706315

# %%
# snr_cut=8.0
# time will take long time sample
ler.selecting_n_lensed_detectable_events(size=10000, batch_size=200000,snr_threshold=8.0, num_img=2, output_jsonfile='n_lensed_detectable_bbh_O4psd_high.json', meta_data_file='n_lensed_detectable_bbh_meta_O4psd_high.json', resume=True)
# Out:
# collected number of detectable events =  1748
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4495.01it/s]
# 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 69.74it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2037
# total number of events =  1400000
# total rate (yr^-1): 0.5360847276289484
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:44<00:00, 4491.92it/s]
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.02it/s]
# given detectability_condition == step_function
# collected number of detectable events =  2335
# total number of events =  1600000
# total rate (yr^-1): 0.5376966662429529
#   9%|████▋                                                 | 17270/200000 [00:03<00:41, 4391.03it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 # snr_cut=8.0
#       2 # time will take long time sample
# ----> 3 ler.selecting_n_lensed_detectable_events(size=10000, batch_size=200000,snr_threshold=8.0, num_img=2, output_jsonfile='n_lensed_detectable_bbh_O4psd_high.json', meta_data_file='n_lensed_detectable_bbh_meta_O4psd_high.json', resume=True)
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:2004, in LeR.selecting_n_lensed_detectable_events(self, size, batch_size, snr_threshold, pdet_threshold, num_img, combine_image_snr, snr_cut_for_combine_image_snr, resume, detectability_condition, output_jsonfile, meta_data_file, trim_to_size, nan_to_num, snr_recalculation, snr_threshold_recalculation)
#    2002 with contextlib.redirect_stdout(None):
#    2003     self.dict_buffer = None  # this is used to store the sampled lensed_param in batches when running the sampling_routine
# -> 2004     lensed_param = self.lensed_sampling_routine(
#    2005         size=self.batch_size, output_jsonfile=buffer_file, resume=False
#    2006     )  # Dimensions are (size, n_max_images)
#    2008 total_events_in_this_iteration = len(lensed_param["zs"])
#    2010 # Below code ensures that the snr is recalculated for the detectable events with inner product
#    2011 # The code is use when the snr is calculated with 'ann' method of `gwsnr`
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:1356, in LeR.lensed_sampling_routine(self, size, output_jsonfile, save_batch, resume)
#    1354 lensed_param_ = self.sample_lens_parameters(size=size)
#    1355 # now get (strongly lensed) image paramters along with lens parameters
# -> 1356 lensed_param_ = self.image_properties(lensed_param_)
#    1358 if len(lensed_param) == 0:  # if empty
#    1359         lensed_param = lensed_param_
#
# File ~/phd/mypackages/ler/ler/image_properties/image_properties.py:253, in ImageProperties.image_properties(self, lens_parameters)
#     249     raise ValueError("n_min_images should be greater than 1")
#     250 with Pool(processes=npool) as pool:
#     251     # call the same function with different data in parallel
#     252     # imap->retain order in the list, while map->doesn't
# --> 253     for result in tqdm(
#     254         pool.imap_unordered(solve_lens_equation_, input_arguments),
#     255         total=len(input_arguments),
#     256         ncols=100,
#     257         disable=False,
#     258     ):
#     259         # print(result)
#     260         (
#     261             x_source_i,
#     262             y_source_i,
#    (...)
#     270             iter_i,
#     271         ) = result
#     273         n_image_i = min(n_image_i, n_max_images)
#
# File ~/anaconda3/envs/ler/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/envs/ler/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# let's see how rate varies with sampling size
meta_data = get_param_from_json('ler_data/n_lensed_detectable_bbh_meta_O4psd_high.json')
# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1.0e6)[0]
# take average 
rate_lensed_high = np.mean(meta_data['total_rate'][idx])
print('Rate (per year) =', rate_lensed_high)
# Out:
# Rate (per year) = 0.5368267311179346

# %%
rate_unlensed_high/rate_lensed_high, rate_unlensed_high, rate_lensed_high
# Out:
# (432.13415107695073, 231.98116372706315, 0.5368267311179346)

# %%
10.694-3.427
# Out:
# 7.267000000000001
