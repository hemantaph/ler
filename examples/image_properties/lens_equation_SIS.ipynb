# %%
# Section 1: Setup and Imports
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import LambdaCDM
import time
import warnings
warnings.filterwarnings("ignore")

# LER imports
from ler.image_properties import (
    caustic_points_epl_shear,
    sample_source_from_double_caustic,
    image_position_analytical_njit
)
from ler.image_properties.cross_section_njit import phi_q2_ellipticity

# Lenstronomy imports
from lenstronomy.LensModel.lens_model import LensModel
from lenstronomy.LensModel.Solver.lens_equation_solver import LensEquationSolver
from lenstronomy.LensModel.Solver.epl_shear_solver import caustics_epl_shear as caustics_lenstronomy
from lenstronomy.Util.param_util import phi_q2_ellipticity as phi_q2_ellipticity_ls

# lenstronomy requires q<1.0 
EPS = 1e-4

# %%
# Section 2: Define Lens Parameters for EPL+Shear Model
# Set up test parameters for EPL+Shear

# Lens parameters (image plane)
theta_E = 1.0  # Einstein radius (normalized)
q = 1.0        # Axis ratio
phi = 0.0  # Position angle (radians)
gamma = 2.0    # Power-law index
gamma1 = 0. # Shear component 1
gamma2 = 0.0 # Shear component 2

# Redshifts for time-delay calculations
zl = 0.8       # Lens redshift
zs = 2.0       # Source redshift

# Setup cosmology
cosmo = LambdaCDM(H0=70, Om0=0.3, Ode0=0.7)
D_s = cosmo.angular_diameter_distance(zs).to('Mpc').value
D_l = cosmo.angular_diameter_distance(zl).to('Mpc').value
D_ls = cosmo.angular_diameter_distance_z1z2(zl, zs).to('Mpc').value

# Physical constants
Mpc_to_m = 3.085677581491367e+22  # Conversion factor
C_LIGHT = 299792458.0  # Speed of light in m/s
D_dt = (1.0 + zl) * (D_l * D_s / D_ls) * Mpc_to_m  # Time-delay distance

# Store lens parameters in a dictionary
lens_params = {
    'theta_E': theta_E,
    'q': q,
    'phi': phi,
    'gamma': gamma,
    'gamma1': gamma1,
    'gamma2': gamma2,
    'zl': zl,
    'zs': zs
}

print(f"Lens parameters for EPL+Shear:")
print(f"  θ_E = {theta_E:.4f}")
print(f"  q = {q:.4f}, φ = {phi:.4f} rad")
print(f"  γ = {gamma:.4f}, (γ₁, γ₂) = ({gamma1:.4f}, {gamma2:.4f})")
print(f"  z_l = {zl}, z_s = {zs}")
# Out:
# Lens parameters for EPL+Shear:
#   θ_E = 1.0000
#   q = 1.0000, φ = 0.0000 rad
#   γ = 2.0000, (γ₁, γ₂) = (0.0000, 0.0000)
#   z_l = 0.8, z_s = 2.0

# %%
# Section 3a: Validate Caustic Calculations - LER Implementation
print("=" * 80)
print("SECTION 3: CAUSTIC VALIDATION")
print("=" * 80)

# Compute caustic points using LER (njit)
print("\n3a. Computing caustic curves using LER (njit)...")
start_time = time.time()
pts_ler = caustic_points_epl_shear(
    theta_E, q, phi, gamma, gamma1, gamma2,
    num_th=500, maginf=-10000.0
)
ler_time = time.time() - start_time
print(f"  LER computation time: {ler_time:.6f} seconds")
print(f"  Caustic points shape: {pts_ler.shape}")
print(f"  All finite: {np.isfinite(pts_ler).all()}")
# Out:
# ================================================================================
# SECTION 3: CAUSTIC VALIDATION
# ================================================================================
#
# 3a. Computing caustic curves using LER (njit)...
#   LER computation time: 0.141491 seconds
#   Caustic points shape: (2, 500)
#   All finite: True

# %%
# Section 3b: Validate Caustic Calculations - Lenstronomy Implementation
print("\n3b. Computing caustic curves using Lenstronomy...")

# Prepare Lenstronomy parameters
e1, e2 = phi_q2_ellipticity_ls(phi, q)
kwargs_lens = [
    {
        'theta_E': theta_E,
        'e1': e1, 'e2': e2,
        'gamma': gamma,
        'center_x': 0.0, 'center_y': 0.0,
    },
    {
        'gamma1': gamma1,
        'gamma2': gamma2,
        'ra_0': 0, 'dec_0': 0,
    },
]

start_time = time.time()
pts_lenstronomy = caustics_lenstronomy(
    kwargs_lens, return_which="double", maginf=-10000.0,
    num_th=500, sourceplane=True
)
ls_time = time.time() - start_time
print(f"  Lenstronomy computation time: {ls_time:.6f} seconds")
print(f"  Caustic points shape: {pts_lenstronomy.shape}")
print(f"  All finite: {np.isfinite(pts_lenstronomy).all()}")
# Out:
# 3b. Computing caustic curves using Lenstronomy...
#   Lenstronomy computation time: 0.032672 seconds
#   Caustic points shape: (2, 500)
#   All finite: True

# %%
# Section 3c: Compare Caustic Results
print("\n3c. Comparing caustic boundaries...")

# Since pts_ler and pts_lenstronomy may have different point sampling,
# we validate that the _boundaries_ (the curves themselves) match,
# not that the individual points are identical.

# Method 1: Check if curve points lie close to each other's boundary
from scipy.spatial.distance import cdist

# Reshape for distance calculation
pts_ler_T = np.column_stack((pts_ler[0], pts_ler[1]))
pts_ls_T = np.column_stack((pts_lenstronomy[0], pts_lenstronomy[1]))

# Find min distance from LER points to Lenstronomy curve
dist_ler_to_ls = np.min(cdist(pts_ler_T, pts_ls_T), axis=1)
max_dist_ler = np.max(dist_ler_to_ls)
mean_dist_ler = np.mean(dist_ler_to_ls)

# Find min distance from Lenstronomy points to LER curve
dist_ls_to_ler = np.min(cdist(pts_ls_T, pts_ler_T), axis=1)
max_dist_ls = np.max(dist_ls_to_ler)
mean_dist_ls = np.mean(dist_ls_to_ler)

print(f"  Max distance (LER→Lenstronomy boundary): {max_dist_ler:.2e}")
print(f"  Mean distance (LER→Lenstronomy boundary): {mean_dist_ler:.2e}")
print(f"  Max distance (Lenstronomy→LER boundary): {max_dist_ls:.2e}")
print(f"  Mean distance (Lenstronomy→LER boundary): {mean_dist_ls:.2e}")

# Check boundary agreement (points lie close to the curve)
boundary_threshold = 1e-3  # arcsec
agree_boundary = (max_dist_ler < boundary_threshold) and (max_dist_ls < boundary_threshold)
print(f"  Boundary match (threshold={boundary_threshold}): {'✓ PASS' if agree_boundary else '✗ FAIL'}")
print(f"    Note: Boundaries match if all points lie within {boundary_threshold} of the other curve")

# Alternative check: approximate convex hull area ratio
from scipy.spatial import ConvexHull
try:
    hull_ler = ConvexHull(pts_ler_T)
    hull_ls = ConvexHull(pts_ls_T)
    area_ratio = hull_ler.volume / hull_ls.volume  # 'volume' gives area in 2D
    print(f"  Caustic area ratio (LER/Lenstronomy): {area_ratio:.4f}")
    agree_area = 0.95 < area_ratio < 1.05
    print(f"  Area match (±5%): {'✓ PASS' if agree_area else '✗ FAIL'}")
except:
    print(f"  Area comparison: Could not compute (degenerate caustic?)")
    agree_area = agree_boundary
# Out:
# 3c. Comparing caustic boundaries...
#   Max distance (LER→Lenstronomy boundary): 4.72e-08
#   Mean distance (LER→Lenstronomy boundary): 3.34e-09
#   Max distance (Lenstronomy→LER boundary): 4.72e-08
#   Mean distance (Lenstronomy→LER boundary): 3.34e-09
#   Boundary match (threshold=0.001): ✓ PASS
#     Note: Boundaries match if all points lie within 0.001 of the other curve
#   Caustic area ratio (LER/Lenstronomy): 1.0000
#   Area match (±5%): ✓ PASS

# %%
# Section 3d: Visualize Caustic Curves
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: Caustic curves overlaid
ax = axes[0]
ax.plot(pts_ler[0], pts_ler[1], 'b-', linewidth=2.5, label='LER (njit)', alpha=0.9)
ax.plot(pts_lenstronomy[0], pts_lenstronomy[1], 'r--', linewidth=2.5, label='Lenstronomy', alpha=0.7)
ax.set_xlabel('x (arcsec)')
ax.set_ylabel('y (arcsec)')
ax.set_title('Caustic Curves Comparison')
ax.axis('equal')
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

# Plot 2: Boundary distances
ax = axes[1]
ax.plot(pts_ler_T[:, 0], dist_ler_to_ls, 'b-', linewidth=1.5, label='LER→Lenstronomy distance')
ax.plot(pts_ls_T[:, 0], dist_ls_to_ler, 'r--', linewidth=1.5, label='Lenstronomy→LER distance')
ax.axhline(boundary_threshold, color='g', linestyle=':', linewidth=2, label=f'Threshold ({boundary_threshold})')
ax.set_xlabel('x position (arcsec)')
ax.set_ylabel('Distance to boundary (arcsec)')
ax.set_title('Point-to-Boundary Distances')
ax.set_yscale('log')
ax.grid(True, alpha=0.3, which='both')
ax.legend(fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Section 4: Validate Source Sampling
print("\n" + "=" * 80)
print("SECTION 4: SOURCE SAMPLING VALIDATION")
print("=" * 80)

# Sample source positions from within the double-imaging caustic region
num_samples = 500
print(f"\nSampling {num_samples} source positions from double-imaging region...")

xs = np.empty(num_samples)
ys = np.empty(num_samples)

start_time = time.time()
for i in range(num_samples):
    xs[i], ys[i] = sample_source_from_double_caustic(
        theta_E, q, phi, gamma, gamma1, gamma2,  maginf = -10000.0,
    )
sampling_time = time.time() - start_time

print(f"  Sampling time: {sampling_time:.6f} seconds")
print(f"  Source position ranges:")
print(f"    x: [{np.min(xs):.6f}, {np.max(xs):.6f}]")
print(f"    y: [{np.min(ys):.6f}, {np.max(ys):.6f}]")

# Verify sources are within caustic bounds (rough check)
caustic_x_range = [np.min(pts_ler[0]), np.max(pts_ler[0])]
caustic_y_range = [np.min(pts_ler[1]), np.max(pts_ler[1])]
sources_in_bounds = np.all((xs >= caustic_x_range[0]) & (xs <= caustic_x_range[1]) &
                           (ys >= caustic_y_range[0]) & (ys <= caustic_y_range[1]))
print(f"  All sources within caustic bounds: {sources_in_bounds}")
# Out:
# ================================================================================
# SECTION 4: SOURCE SAMPLING VALIDATION
# ================================================================================
#
# Sampling 500 source positions from double-imaging region...
#   Sampling time: 0.088161 seconds
#   Source position ranges:
#     x: [-0.968696, 0.979381]
#     y: [-0.993250, 0.988964]
#   All sources within caustic bounds: True

# %%
# Section 4b: Visualize Sampled Sources with Caustics
fig, ax = plt.subplots(figsize=(5, 5))

# Plot caustic
ax.plot(pts_ler[0], pts_ler[1], 'b-', linewidth=2.5, label='Caustic Curve')

# Plot sampled sources
ax.scatter(xs, ys, s=10, color='red', alpha=0.6, label=f'Sampled Sources (n={num_samples})')

ax.set_xlabel('x (arcsec)')
ax.set_ylabel('y (arcsec)')
ax.set_title('EPL+Shear: Caustic and Sampled Source Positions')
ax.axis('equal')
ax.grid(True, alpha=0.3)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Section 5: Validate Lens Equation Solving
print("\n" + "=" * 80)
print("SECTION 5: LENS EQUATION SOLVING VALIDATION")
print("=" * 80)

max_img = 4  # Maximum number of images for EPL+Shear is typically 4

# Arrays to store results
x_img_ler = np.full((num_samples, max_img), np.nan)
y_img_ler = np.full((num_samples, max_img), np.nan)
mu_ler = np.full((num_samples, max_img), np.nan)
tau_ler = np.full((num_samples, max_img), np.nan)
itype_ler = np.full((num_samples, max_img), np.nan)
n_img_ler = np.full(num_samples, 0, dtype=int)

# Solve lens equations using LER (njit)
print(f"\nSolving lens equations using LER (njit) for {num_samples} sources...")
start_time = time.time()
for i in range(num_samples):
    x, y, arrival_time, mu, image_type, n = image_position_analytical_njit(
        x_src=xs[i],
        y_src=ys[i],
        q=q-EPS,  # Avoid q=1.0 for numerical stability
        phi=phi,
        gamma=gamma,
        gamma1=gamma1,
        gamma2=gamma2,
        theta_E=theta_E,
    )

    n = min(n, max_img)
    x_img_ler[i, :n] = x[:n]
    y_img_ler[i, :n] = y[:n]
    mu_ler[i, :n] = mu[:n]
    
    # Convert fermat potential (dimensionless) to physical time delays
    tau_hat = arrival_time[:n]
    tau_phys = tau_hat * (theta_E * theta_E)  # Scale with theta_E^2
    tau_ = (D_dt / C_LIGHT) * tau_phys  # Convert to seconds
    try:
        tau_ = tau_ - np.min(tau_)  # Relative to first arrival
    except:
        tau_ = np.zeros_like(tau_)  # If all arrivals are identical, set to zero
    tau_ler[i, :n] = tau_
    
    itype_ler[i, :n] = image_type[:n]
    n_img_ler[i] = n
        
ler_solve_time = time.time() - start_time
print(f"  LER solving time: {ler_solve_time:.6f} seconds")
print(f"  Average images per source: {np.mean(n_img_ler[n_img_ler > 0]):.2f}")
# Out:
# ================================================================================
# SECTION 5: LENS EQUATION SOLVING VALIDATION
# ================================================================================
#
# Solving lens equations using LER (njit) for 500 sources...
#   LER solving time: 0.133605 seconds
#   Average images per source: 1.71

# %%
# Section 5b: Solve using Lenstronomy
print("\nSolving lens equations using Lenstronomy for comparison...")

# Setup Lenstronomy lens model
lens_model_list = ["EPL", "SHEAR"]
lensModel = LensModel(lens_model_list=lens_model_list, z_lens=zl, z_source=zs, cosmo=cosmo)
lens_eq_solver = LensEquationSolver(lensModel)

# Arrays to store Lenstronomy results
x_img_ls = np.full((num_samples, max_img), np.nan)
y_img_ls = np.full((num_samples, max_img), np.nan)
mu_ls = np.full((num_samples, max_img), np.nan)
tau_ls = np.full((num_samples, max_img), np.nan)
itype_ls = np.full((num_samples, max_img), np.nan)
n_img_ls = np.full(num_samples, 0, dtype=int)

e1, e2 = phi_q2_ellipticity_ls(phi, q-EPS)  # Ensure q<1 for lenstronomy
kwargs_lens = [
    {
        'theta_E': theta_E,
        'e1': e1, 'e2': e2,
        'gamma': gamma,
        'center_x': 0.0, 'center_y': 0.0,
    },
    {
        'gamma1': gamma1,
        'gamma2': gamma2,
        'ra_0': 0, 'dec_0': 0,
    },
]

start_time = time.time()
for i in range(num_samples):
    # Solve image positions
    theta_ra, theta_dec = lens_eq_solver.image_position_from_source(
        sourcePos_x=xs[i], sourcePos_y=ys[i],
        kwargs_lens=kwargs_lens,
        solver="analytical", magnification_limit=1.0/100.0,
        arrival_time_sort=True
    )
    n = min(len(theta_ra), max_img)
    x_img_ls[i, :n] = theta_ra[:n]
    y_img_ls[i, :n] = theta_dec[:n]

    # Compute magnifications
    magnifications = lensModel.magnification(theta_ra, theta_dec, kwargs_lens)
    mu_ls[i, :n] = magnifications[:n]

    # Compute image types
    hessian = lensModel.hessian(theta_ra, theta_dec, kwargs_lens)
    determinant = (1 - hessian[0]) * (1 - hessian[3]) - hessian[1] * hessian[2]
    trace = 2 - hessian[0] - hessian[3]
    
    image_type_ls = []
    for j in range(len(theta_ra)):
        if determinant[j] < 0:
            image_type_ls.append(2.0)  
        elif trace[j] > 0:
            image_type_ls.append(1.0)  
        elif trace[j] < 0:
            image_type_ls.append(3.0)  
        else:
            image_type_ls.append(np.nan)
    itype_ls[i, :n] = image_type_ls[:n]

    # Compute time delays
    radian_to_arcseconds = 180.0 / np.pi * 3600.0
    days_to_seconds = 24.0 * 3600.0
    tau_tmp = (
        lensModel.arrival_time(theta_ra, theta_dec, kwargs_lens)
        * (radian_to_arcseconds) ** 2
        * days_to_seconds
    )[:n]
    try:
        tau_tmp = tau_tmp - np.min(tau_tmp)  # Convert to positive time delays relative to first arrival
    except:
        tau_tmp = np.zeros_like(tau_tmp)  # If all arrivals are identical, set to zero
    tau_ls[i, :n] = tau_tmp[:n]
    
    n_img_ls[i] = n

ls_solve_time = time.time() - start_time
print(f"  Lenstronomy solving time: {ls_solve_time:.6f} seconds")
print(f"  Average images per source: {np.mean(n_img_ls[n_img_ls > 0]):.2f}")
# Out:
# Solving lens equations using Lenstronomy for comparison...
#   Lenstronomy solving time: 0.333918 seconds
#   Average images per source: 1.84

# %%
# Section 6: Compare Results with Lenstronomy
print("\n" + "=" * 80)
print("SECTION 6: RESULT COMPARISON")
print("=" * 80)

# Compare number of images
n_img_match = np.sum(n_img_ler == n_img_ls)
n_img_total = np.sum((n_img_ler > 0) & (n_img_ls > 0))
print(f"\nImage count agreement: {n_img_match}/{n_img_total} ({100*n_img_match/max(n_img_total, 1):.1f}%)")

# Compare image positions (normalized by theta_E for dimensionless comparison)
valid_mask = (np.isfinite(x_img_ler)) & (np.isfinite(x_img_ls))
x_diff = x_img_ler[valid_mask] - x_img_ls[valid_mask]
y_diff = y_img_ler[valid_mask] - y_img_ls[valid_mask]

if len(x_diff) > 0:
    x_agree = np.sum(np.abs(x_diff) < 0.02) / len(x_diff)
    y_agree = np.sum(np.abs(y_diff) < 0.02) / len(y_diff)
    print(f"\nImage position agreement (tolerance=0.02):")
    print(f"  x-coordinate: {100*x_agree:.1f}%")
    print(f"  y-coordinate: {100*y_agree:.1f}%")
    print(f"  Max |Δx|: {np.max(np.abs(x_diff)):.2e}")
    print(f"  Max |Δy|: {np.max(np.abs(y_diff)):.2e}")
    print(f"  Mean |Δx|: {np.mean(np.abs(x_diff)):.2e}")
    print(f"  Mean |Δy|: {np.mean(np.abs(y_diff)):.2e}")

# Compare magnifications
valid_mag = (np.isfinite(mu_ler)) & (np.isfinite(mu_ls))
mu_diff_rel = np.abs((mu_ler[valid_mag] - mu_ls[valid_mag]) / mu_ls[valid_mag])

if len(mu_diff_rel) > 0:
    mu_agree = np.sum(mu_diff_rel < 0.05) / len(mu_diff_rel)
    print(f"\nMagnification agreement (relative tolerance=5%):")
    print(f"  Cases within tolerance: {100*mu_agree:.1f}%")
    print(f"  Max relative error: {100*np.max(mu_diff_rel):.2f}%")
    print(f"  Mean relative error: {100*np.mean(mu_diff_rel):.2f}%")

# Compare time delays
valid_tau = (np.isfinite(tau_ler)) & (np.isfinite(tau_ls)) & (tau_ls != 0)
tau_diff_rel = np.abs((tau_ler[valid_tau] - tau_ls[valid_tau]) / tau_ls[valid_tau])

if len(tau_diff_rel) > 0:
    tau_agree = np.sum(tau_diff_rel < 0.10) / len(tau_diff_rel)
    print(f"\nTime delay agreement (relative tolerance=10%):")
    print(f"  Cases within tolerance: {100*tau_agree:.1f}%")
    print(f"  Max relative error: {100*np.max(tau_diff_rel):.2f}%")
    print(f"  Mean relative error: {100*np.mean(tau_diff_rel):.2f}%")

# Compare image types
valid_mask = np.isfinite(itype_ler) & np.isfinite(itype_ls)
itype_match = np.sum(itype_ler[valid_mask] == itype_ls[valid_mask])
itype_total = np.sum(valid_mask)

if itype_total > 0:
    print(f"\nImage type classification agreement: {itype_match}/{itype_total} ({100*itype_match/itype_total:.1f}%)")
# Out:
# ================================================================================
# SECTION 6: RESULT COMPARISON
# ================================================================================
#
# Image count agreement: 429/496 (86.5%)
#
# Image position agreement (tolerance=0.02):
#   x-coordinate: 100.0%
#   y-coordinate: 100.0%
#   Max |Δx|: 3.85e-09
#   Max |Δy|: 7.95e-09
#   Mean |Δx|: 1.42e-10
#   Mean |Δy|: 1.81e-10
#
# Magnification agreement (relative tolerance=5%):
#   Cases within tolerance: 100.0%
#   Max relative error: 0.00%
#   Mean relative error: 0.00%
#
# Time delay agreement (relative tolerance=10%):
#   Cases within tolerance: 100.0%
#   Max relative error: 0.00%
#   Mean relative error: 0.00%
#
# Image type classification agreement: 847/847 (100.0%)

# %%
# Find and print indices where image counts don't match
mismatch_indices = np.where(n_img_ler != n_img_ls)[0]

# print image properties for mismatches
if len(mismatch_indices) > 0:

    for idx in mismatch_indices:
        print(f"\nIndex {idx}")
        print(f"Source position: (x={xs[idx]:.4f}, y={ys[idx]:.4f})")
        print(f"LER={n_img_ler[idx]}, image positions: {x_img_ler[idx, :n_img_ler[idx]]}, {y_img_ler[idx, :n_img_ler[idx]]}, magnifications: {mu_ler[idx, :n_img_ler[idx]]}, time delays: {tau_ler[idx, :n_img_ler[idx]]}, types: {itype_ler[idx, :n_img_ler[idx]]}")
        print(f"Lenstronomy={n_img_ls[idx]}, image positions: {x_img_ls[idx, :n_img_ls[idx]]}, {y_img_ls[idx, :n_img_ls[idx]]}, magnifications: {mu_ls[idx, :n_img_ls[idx]]}, time delays: {tau_ls[idx, :n_img_ls[idx]]}, types: {itype_ls[idx, :n_img_ls[idx]]}")
else:
    print("\nNo mismatches in image count!")
# Out:
# Index 2
# Source position: (x=0.5727, y=0.6098)
# LER=1, image positions: [1.25719397], [1.3388408], magnifications: [2.19533265], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.25719397 -0.11187572], [ 1.3388408  -0.11912236], magnifications: [ 2.19533265 -0.19534462], time delays: [0.00000000e+00 1.03951667e+18], types: [1. 2.]
#
# Index 25
# Source position: (x=-0.6289, y=0.6912)
# LER=1, image positions: [-1.30182319], [1.43090182], magnifications: [2.07010023], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.30182319  0.04409581], [ 1.43090182 -0.04846109], magnifications: [ 2.07010023 -0.07011462], time delays: [0.00000000e+00 1.16116673e+18], types: [1. 2.]
#
# Index 32
# Source position: (x=0.8752, y=0.1829)
# LER=1, image positions: [1.85404689], [0.38749744], magnifications: [2.118542], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.85404689 -0.10362336], [ 0.38749744 -0.02165414], magnifications: [ 2.118542   -0.11838917], time delays: [0.00000000e+00 1.11099977e+18], types: [1. 2.]
#
# Index 34
# Source position: (x=-0.7821, y=-0.3323)
# LER=1, image positions: [-1.70247461], [-0.72345731], magnifications: [2.17681756], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.70247461  0.13820598], [-0.72345731  0.05872067], magnifications: [ 2.17681756 -0.17668941], time delays: [0.00000000e+00 1.05596101e+18], types: [1. 2.]
#
# Index 42
# Source position: (x=-0.2026, y=0.9015)
# LER=1, image positions: [-0.42183359], [1.87714664], magnifications: [2.08219578], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.42183359  0.01668082], [ 1.87714664 -0.07421843], magnifications: [ 2.08219578 -0.08233695], time delays: [0.00000000e+00 1.14809039e+18], types: [1. 2.]
#
# Index 47
# Source position: (x=0.2961, y=0.8107)
# LER=1, image positions: [0.6391781], [1.75005487], magnifications: [2.15848299], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.6391781  -0.04697196], [ 1.75005487 -0.12858827], magnifications: [ 2.15848299 -0.15861984], time delays: [0.00000000e+00 1.07249912e+18], types: [1. 2.]
#
# Index 48
# Source position: (x=-0.8810, y=0.1990)
# LER=1, image positions: [-1.85639221], [0.41935138], magnifications: [2.10731933], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.85639221  0.09442362], [ 0.41935138 -0.02132676], magnifications: [ 2.10731932 -0.10717173], time delays: [0.00000000e+00 1.12225737e+18], types: [1. 2.]
#
# Index 50
# Source position: (x=-0.3744, y=-0.8554)
# LER=1, image positions: [-0.77524649], [-1.77156205], magnifications: [2.07086034], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.77524649  0.02656671], [-1.77156205  0.0607005 ], magnifications: [ 2.07086034 -0.07096411], time delays: [0.0000000e+00 1.1602715e+18], types: [1. 2.]
#
# Index 68
# Source position: (x=0.3616, y=0.8511)
# LER=1, image positions: [0.75265682], [1.77146099], magnifications: [2.08132445], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.75265682 -0.02944866], [ 1.77146099 -0.06930069], magnifications: [ 2.08132445 -0.08143269], time delays: [0.00000000e+00 1.14904098e+18], types: [1. 2.]
#
# Index 70
# Source position: (x=-0.3539, y=0.8484)
# LER=1, image positions: [-0.73874168], [1.77139272], magnifications: [2.08774775], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.73874168  0.03108917], [ 1.77139272 -0.07453639], magnifications: [ 2.08774775 -0.08785878], time delays: [0.00000000e+00 1.14225425e+18], types: [1. 2.]
#
# Index 76
# Source position: (x=-0.8591, y=0.3235)
# LER=1, image positions: [-1.79492528], [0.67602916], magnifications: [2.08939525], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.79492528  0.07670389], [ 0.67602916 -0.02888506], magnifications: [ 2.08939525 -0.08927633], time delays: [0.00000000e+00 1.14070261e+18], types: [1. 2.]
#
# Index 81
# Source position: (x=0.3472, y=0.8263)
# LER=1, image positions: [0.73443704], [1.74827975], magnifications: [2.11563948], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.73443704 -0.04018508], [ 1.74827975 -0.09564376], magnifications: [ 2.11563948 -0.11575567], time delays: [0.00000000e+00 1.11369611e+18], types: [1. 2.]
#
# Index 82
# Source position: (x=0.3358, y=0.7860)
# LER=1, image positions: [0.72853322], [1.70567099], magnifications: [2.16985359], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.72853322 -0.05707247], [ 1.70567099 -0.13359949], magnifications: [ 2.16985359 -0.16997978], time delays: [0.00000000e+00 1.06208282e+18], types: [1. 2.]
#
# Index 85
# Source position: (x=-0.1875, y=0.8383)
# LER=1, image positions: [-0.40570322], [1.81418463], magnifications: [2.16403769], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.40570322  0.03078386], [ 1.81418463 -0.13763495], magnifications: [ 2.16403769 -0.16420118], time delays: [0.00000000e+00 1.06736434e+18], types: [1. 2.]
#
# Index 93
# Source position: (x=0.6965, y=-0.5713)
# LER=1, image positions: [1.46965097], [-1.20556285], magnifications: [2.1100775], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.46965097 -0.07665245], [-1.20556285  0.06286912], magnifications: [ 2.1100775  -0.11004538], time delays: [0.00000000e+00 1.11938411e+18], types: [1. 2.]
#
# Index 97
# Source position: (x=-0.5736, y=-0.7326)
# LER=1, image positions: [-1.19007106], [-1.51999796], magnifications: [2.07471433], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.19007106  0.04288021], [-1.51999796  0.05476017], magnifications: [ 2.07471433 -0.07475129], time delays: [0.00000000e+00 1.15616374e+18], types: [1. 2.]
#
# Index 110
# Source position: (x=0.1916, y=-0.8191)
# LER=1, image positions: [0.41923303], [-1.79289201], magnifications: [2.18858434], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.41923303 -0.03615681], [-1.79289201  0.15460371], magnifications: [ 2.18858434 -0.18875321], time delays: [0.00000000e+00 1.04532057e+18], types: [1. 2.]
#
# Index 124
# Source position: (x=-0.1494, y=0.8018)
# LER=1, image positions: [-0.33259725], [1.78487473], magnifications: [2.22596582], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.33259725  0.03379127], [ 1.78487473 -0.18131036], magnifications: [ 2.22596582 -0.22615281], time delays: [0.0000000e+00 1.0134407e+18], types: [1. 2.]
#
# Index 128
# Source position: (x=0.5182, y=0.7407)
# LER=1, image positions: [1.09140683], [1.56009252], magnifications: [2.10620567], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.09140683 -0.05506598], [ 1.56009252 -0.07870149], magnifications: [ 2.10620567 -0.10626161], time delays: [0.00000000e+00 1.12323726e+18], types: [1. 2.]
#
# Index 130
# Source position: (x=-0.5219, y=-0.0004)
# LER=0, image positions: [], [], magnifications: [], time delays: [], types: []
# Lenstronomy=1, image positions: [-1.52192642], [-0.00107691], magnifications: [2.91625687], time delays: [0.], types: [1.]
#
# Index 133
# Source position: (x=-0.4408, y=-0.8351)
# LER=1, image positions: [-0.9076206], [-1.71945429], magnifications: [2.05892522], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.9076206   0.02601355], [-1.71945429  0.04927477], magnifications: [ 2.05892522 -0.05900958], time delays: [0.00000000e+00 1.17336348e+18], types: [1. 2.]
#
# Index 138
# Source position: (x=-0.6188, y=0.5553)
# LER=1, image positions: [-1.36303448], [1.22316676], magnifications: [2.20281504], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.36303448  0.12549401], [ 1.22316676 -0.11259839], magnifications: [ 2.20281504 -0.20279423], time delays: [0.0000000e+00 1.0330701e+18], types: [1. 2.]
#
# Index 140
# Source position: (x=-0.6426, y=0.6522)
# LER=1, image positions: [-1.3443961], [1.36456724], magnifications: [2.0922028], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.3443961   0.05925294], [ 1.36456724 -0.0601332 ], magnifications: [ 2.0922028  -0.09220517], time delays: [0.00000000e+00 1.13767798e+18], types: [1. 2.]
#
# Index 144
# Source position: (x=-0.8330, y=0.3010)
# LER=1, image positions: [-1.77347748], [0.64080467], magnifications: [2.1291468], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.77347748  0.10747853], [ 0.64080467 -0.03882901], magnifications: [ 2.1291468  -0.12901607], time delays: [0.00000000e+00 1.10054852e+18], types: [1. 2.]
#
# Index 145
# Source position: (x=0.8284, y=0.1901)
# LER=1, image positions: [1.80303156], [0.41387847], magnifications: [2.17669125], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.80303156 -0.14624391], [ 0.41387847 -0.03356442], magnifications: [ 2.17669125 -0.17652514], time delays: [0.00000000e+00 1.05609865e+18], types: [1. 2.]
#
# Index 147
# Source position: (x=0.7123, y=0.5920)
# LER=1, image positions: [1.48135036], [1.23123863], magnifications: [2.07967037], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.48135036 -0.05673384], [ 1.23123863 -0.04714809], magnifications: [ 2.07967037 -0.07964196], time delays: [0.00000000e+00 1.15090772e+18], types: [1. 2.]
#
# Index 152
# Source position: (x=-0.7917, y=-0.1550)
# LER=1, image positions: [-1.77308072], [-0.34725254], magnifications: [2.23964696], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.77308072  0.18960336], [-0.34725254  0.03712711], magnifications: [ 2.23964696 -0.23945723], time delays: [0.00000000e+00 1.00247131e+18], types: [1. 2.]
#
# Index 157
# Source position: (x=0.7713, y=-0.0026)
# LER=0, image positions: [], [], magnifications: [], time delays: [], types: []
# Lenstronomy=1, image positions: [1.77127789], [-0.00592134], magnifications: [2.29668181], time delays: [0.], types: [1.]
#
# Index 160
# Source position: (x=0.8071, y=-0.2026)
# LER=1, image positions: [1.77699311], [-0.44612681], magnifications: [2.2018388], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.77699311 -0.16278147], [-0.44612681  0.0408609 ], magnifications: [ 2.2018388  -0.20166907], time delays: [0.00000000e+00 1.03399999e+18], types: [1. 2.]
#
# Index 168
# Source position: (x=0.8005, y=-0.2081)
# LER=1, image positions: [1.76826015], [-0.45973946], magnifications: [2.20923635], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.76826015 -0.16736058], [-0.45973946  0.04350596], magnifications: [ 2.20923635 -0.20906609], time delays: [0.00000000e+00 1.02767396e+18], types: [1. 2.]
#
# Index 174
# Source position: (x=0.6421, y=0.5212)
# LER=1, image positions: [1.41849876], [1.15148587], magnifications: [2.2091655], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.41849876 -0.13429188], [ 1.15148587 -0.1089957 ], magnifications: [ 2.2091655  -0.20912542], time delays: [0.00000000e+00 1.02765597e+18], types: [1. 2.]
#
# Index 176
# Source position: (x=0.1970, y=-0.9211)
# LER=1, image positions: [0.40621826], [-1.89896766], magnifications: [2.06155035], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.40621826 -0.01215529], [-1.89896766  0.05681485], magnifications: [ 2.06155035 -0.06168748], time delays: [0.00000000e+00 1.17041928e+18], types: [1. 2.]
#
# Index 180
# Source position: (x=-0.4847, y=-0.7410)
# LER=1, image positions: [-1.03195654], [-1.57797504], magnifications: [2.12931501], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.03195654  0.06270742], [-1.57797504  0.0958721 ], magnifications: [ 2.12931501 -0.12938318], time delays: [0.00000000e+00 1.10024477e+18], types: [1. 2.]
#
# Index 188
# Source position: (x=0.7422, y=-0.3174)
# LER=1, image positions: [1.66156597], [-0.71069009], magnifications: [2.23898434], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.66156597 -0.17727181], [-0.71069009  0.07581072], magnifications: [ 2.23898434 -0.23884299], time delays: [0.00000000e+00 1.00298002e+18], types: [1. 2.]
#
# Index 193
# Source position: (x=0.6054, y=-0.5961)
# LER=1, image positions: [1.31794761], [-1.29777477], magnifications: [2.17695713], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.31794761 -0.1071381 ], [-1.29777477  0.10548167], magnifications: [ 2.17695713 -0.17695428], time delays: [0.00000000e+00 1.05575568e+18], types: [1. 2.]
#
# Index 197
# Source position: (x=-0.6174, y=0.6175)
# LER=1, image positions: [-1.3243769], [1.32472079], magnifications: [2.14521959], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.3243769   0.08965992], [ 1.32472079 -0.0896695 ], magnifications: [ 2.14521959 -0.14521963], time delays: [0.00000000e+00 1.08501201e+18], types: [1. 2.]
#
# Index 201
# Source position: (x=0.7850, y=0.1592)
# LER=1, image positions: [1.76496837], [0.35809716], magnifications: [2.24867869], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.76496837 -0.19506668], [ 0.35809716 -0.03957079], magnifications: [ 2.24867869 -0.24848726], time delays: [0.00000000e+00 9.95220357e+17], types: [1. 2.]
#
# Index 213
# Source position: (x=0.3379, y=0.8146)
# LER=1, image positions: [0.72103035], [1.73828233], magnifications: [2.13384272], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.72103035 -0.04526769], [ 1.73828233 -0.10911625], magnifications: [ 2.13384272 -0.13396383], time delays: [0.00000000e+00 1.09581462e+18], types: [1. 2.]
#
# Index 215
# Source position: (x=0.8192, y=-0.3912)
# LER=1, image positions: [1.72152128], [-0.82215557], magnifications: [2.10167691], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.72152128 -0.08321202], [-0.82215557  0.03973415], magnifications: [ 2.10167691 -0.1015752 ], time delays: [0.00000000e+00 1.12797176e+18], types: [1. 2.]
#
# Index 218
# Source position: (x=-0.6571, y=-0.6245)
# LER=1, image positions: [-1.38183199], [-1.31351678], magnifications: [2.10313587], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.38183199  0.06776362], [-1.31351678  0.06440404], magnifications: [ 2.10313587 -0.10312765], time delays: [0.00000000e+00 1.12641045e+18], types: [1. 2.]
#
# Index 221
# Source position: (x=-0.1620, y=-0.7903)
# LER=1, image positions: [-0.36271365], [-1.76999972], magnifications: [2.23936503], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.36271365  0.03880111], [-1.76999972  0.18931355], magnifications: [ 2.23936503 -0.23955337], time delays: [0.00000000e+00 1.00248477e+18], types: [1. 2.]
#
# Index 228
# Source position: (x=0.6447, y=0.5949)
# LER=1, image positions: [1.37954128], [1.27308166], magnifications: [2.14000368], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.37954128 -0.09025104], [ 1.27308166 -0.08327368], magnifications: [ 2.14000368 -0.1399898 ], time delays: [0.00000000e+00 1.08998589e+18], types: [1. 2.]
#
# Index 230
# Source position: (x=-0.6460, y=-0.5427)
# LER=1, image positions: [-1.4116688], [-1.1859395], magnifications: [2.18526571], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.4116688   0.11967077], [-1.1859395   0.10051924], magnifications: [ 2.18526571 -0.1852334 ], time delays: [0.00000000e+00 1.04837347e+18], types: [1. 2.]
#
# Index 254
# Source position: (x=-0.8554, y=0.2955)
# LER=1, image positions: [-1.80052273], [0.6220266], magnifications: [2.10513626], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.80052273  0.08982528], [ 0.6220266  -0.03102737], magnifications: [ 2.10513626 -0.10500815], time delays: [0.00000000e+00 1.12446013e+18], types: [1. 2.]
#
# Index 265
# Source position: (x=-0.5914, y=-0.6082)
# LER=1, image positions: [-1.28848025], [-1.32513186], magnifications: [2.1788461], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.28848025  0.10577341], [-1.32513186  0.1087651 ], magnifications: [ 2.1788461 -0.1788513], time delays: [0.00000000e+00 1.05405882e+18], types: [1. 2.]
#
# Index 273
# Source position: (x=-0.6450, y=0.5853)
# LER=1, image positions: [-1.38550155], [1.25738718], magnifications: [2.14811893], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.38550155  0.09553134], [ 1.25738718 -0.08668449], magnifications: [ 2.14811893 -0.14810193], time delays: [0.00000000e+00 1.08228356e+18], types: [1. 2.]
#
# Index 277
# Source position: (x=0.6229, y=0.7043)
# LER=1, image positions: [1.28537734], [1.45335024], magnifications: [2.06357673], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.28537734 -0.03961514], [ 1.45335024 -0.04478568], magnifications: [ 2.06357673 -0.06359516], time delays: [0.00000000e+00 1.16828544e+18], types: [1. 2.]
#
# Index 281
# Source position: (x=-0.7238, y=0.5541)
# LER=1, image positions: [-1.51774629], [1.16199523], magnifications: [2.09713705], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.51774629  0.07027649], [ 1.16199523 -0.05379621], magnifications: [ 2.09713705 -0.09709517], time delays: [0.00000000e+00 1.13259466e+18], types: [1. 2.]
#
# Index 284
# Source position: (x=0.6217, y=0.7081)
# LER=1, image positions: [1.28136823], [1.45966528], magnifications: [2.06121956], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.28136823 -0.03807191], [ 1.45966528 -0.04336332], magnifications: [ 2.06121956 -0.06123902], time delays: [0.00000000e+00 1.17087955e+18], types: [1. 2.]
#
# Index 290
# Source position: (x=0.6208, y=0.6606)
# LER=1, image positions: [1.30558848], [1.38938921], magnifications: [2.10306609], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.30558848 -0.06399435], [ 1.38938921 -0.06809188], magnifications: [ 2.10306609 -0.10307617], time delays: [0.00000000e+00 1.12646813e+18], types: [1. 2.]
#
# Index 296
# Source position: (x=0.0008, y=0.8818)
# LER=1, image positions: [0.00161411], [1.88184528], magnifications: [2.13386389], time delays: [0.], types: [1.]
# Lenstronomy=0, image positions: [], [], magnifications: [], time delays: [], types: []
#
# Index 300
# Source position: (x=0.2105, y=-0.8613)
# LER=1, image positions: [0.44790212], [-1.83269752], magnifications: [2.12775172], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.44790212 -0.02692427], [-1.83269752  0.11015045], magnifications: [ 2.12775172 -0.12790221], time delays: [0.00000000e+00 1.10171182e+18], types: [1. 2.]
#
# Index 321
# Source position: (x=0.8006, y=-0.1460)
# LER=1, image positions: [1.78437267], [-0.32539397], magnifications: [2.22893269], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.78437267 -0.18315036], [-0.32539397  0.03339339], magnifications: [ 2.22893269 -0.2287443 ], time delays: [0.00000000e+00 1.01121165e+18], types: [1. 2.]
#
# Index 338
# Source position: (x=-0.7422, y=-0.5283)
# LER=1, image positions: [-1.55685811], [-1.10820622], magnifications: [2.09773027], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.55685811  0.07249981], [-1.10820622  0.05159942], magnifications: [ 2.09773027 -0.09767767], time delays: [0.00000000e+00 1.13199063e+18], types: [1. 2.]
#
# Index 342
# Source position: (x=0.1429, y=-0.7722)
# LER=1, image positions: [0.32490168], [-1.75552031], magnifications: [2.27321061], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.32490168 -0.03907807], [-1.75552031  0.21111215], magnifications: [ 2.27321061 -0.27341249], time delays: [0.00000000e+00 9.75832171e+17], types: [1. 2.]
#
# Index 357
# Source position: (x=0.8595, y=-0.3702)
# LER=1, image positions: [1.77788097], [-0.76583546], magnifications: [2.06866763], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.77788097 -0.05893241], [-0.76583546  0.02538196], magnifications: [ 2.06866763 -0.06856303], time delays: [0.00000000e+00 1.16281833e+18], types: [1. 2.]
#
# Index 358
# Source position: (x=-0.6993, y=0.5694)
# LER=1, image positions: [-1.47471834], [1.20088416], magnifications: [2.10889318], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.47471834  0.07613096], [ 1.20088416 -0.06198536], magnifications: [ 2.10889318 -0.10885997], time delays: [0.00000000e+00 1.12058047e+18], types: [1. 2.]
#
# Index 363
# Source position: (x=0.5482, y=-0.6371)
# LER=1, image positions: [1.2003817], [-1.39518467], magnifications: [2.1897423], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.2003817  -0.10403616], [-1.39518467  0.1209004 ], magnifications: [ 2.1897423  -0.18977047], time delays: [0.000000e+00 1.044391e+18], types: [1. 2.]
#
# Index 378
# Source position: (x=-0.6857, y=-0.6103)
# LER=1, image positions: [-1.43261871], [-1.27513408], magnifications: [2.0894494], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.43261871  0.06132285], [-1.27513408  0.05457384], magnifications: [ 2.0894494  -0.08943106], time delays: [0.00000000e+00 1.14056908e+18], types: [1. 2.]
#
# Index 393
# Source position: (x=-0.3013, y=-0.8049)
# LER=1, image positions: [-0.65183156], [-1.74150881], magnifications: [2.16337328], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.65183156  0.04926687], [-1.74150881  0.13160666], magnifications: [ 2.16337328 -0.16350941], time delays: [0.00000000e+00 1.06799179e+18], types: [1. 2.]
#
# Index 395
# Source position: (x=0.1812, y=-0.8080)
# LER=1, image positions: [0.39999144], [-1.78375183], magnifications: [2.20753723], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.39999144 -0.03763655], [-1.78375183  0.16781224], magnifications: [ 2.20753723 -0.20771307], time delays: [0.00000000e+00 1.02891166e+18], types: [1. 2.]
#
# Index 415
# Source position: (x=0.7305, y=0.5482)
# LER=1, image positions: [1.53033208], [1.14852552], magnifications: [2.09486532], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.53033208 -0.06927446], [ 1.14852552 -0.0519834 ], magnifications: [ 2.09486532 -0.09482067], time delays: [0.00000000e+00 1.13494686e+18], types: [1. 2.]
#
# Index 418
# Source position: (x=-0.8527, y=0.3284)
# LER=1, image positions: [-1.78590605], [0.68776513], magnifications: [2.09446304], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.78590605  0.08045594], [ 0.68776513 -0.03097963], magnifications: [ 2.09446304 -0.09434459], time delays: [0.00000000e+00 1.13541981e+18], types: [1. 2.]
#
# Index 447
# Source position: (x=-0.6093, y=-0.6692)
# LER=1, image positions: [-1.2825319], [-1.40864754], magnifications: [2.10491312], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.2825319   0.06393753], [-1.40864754  0.07021437], magnifications: [ 2.10491312 -0.10492835], time delays: [0.00000000e+00 1.12458127e+18], types: [1. 2.]
#
# Index 448
# Source position: (x=-0.3032, y=0.7568)
# LER=1, image positions: [-0.67507925], [1.68511583], magnifications: [2.22642982], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-0.67507925  0.06870169], [ 1.68511583 -0.17146338], magnifications: [ 2.22642982 -0.22657492], time delays: [0.00000000e+00 1.01308168e+18], types: [1. 2.]
#
# Index 457
# Source position: (x=0.3522, y=-0.8203)
# LER=1, image positions: [0.74661823], [-1.73923308], magnifications: [2.12009639], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.74661824 -0.042335  ], [-1.73923308  0.09860386], magnifications: [ 2.12009639 -0.12021163], time delays: [0.00000000e+00 1.10926578e+18], types: [1. 2.]
#
# Index 459
# Source position: (x=0.2345, y=0.8458)
# LER=1, image positions: [0.5016745], [1.80943468], magnifications: [2.13924602], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 0.5016745  -0.03268973], [ 1.80943468 -0.11788708], magnifications: [ 2.13924602 -0.1393944 ], time delays: [0.00000000e+00 1.09059905e+18], types: [1. 2.]
#
# Index 461
# Source position: (x=0.9184, y=0.0052)
# LER=0, image positions: [], [], magnifications: [], time delays: [], types: []
# Lenstronomy=1, image positions: [1.91839705], [0.01096349], magnifications: [2.08893025], time delays: [0.], types: [1.]
#
# Index 485
# Source position: (x=0.8608, y=-0.2929)
# LER=1, image positions: [1.80752276], [-0.61505063], magnifications: [2.09983878], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.80752276 -0.08584161], [-0.61505063  0.02920527], magnifications: [ 2.09983878 -0.09971098], time delays: [0.00000000e+00 1.12987657e+18], types: [1. 2.]
#
# Index 491
# Source position: (x=0.5099, y=-0.7541)
# LER=1, image positions: [1.06993825], [-1.5826083], magnifications: [2.09844204], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [ 1.06993825 -0.05022578], [-1.5826083   0.07428102], magnifications: [ 2.09844204 -0.098502  ], time delays: [0.00000000e+00 1.13117274e+18], types: [1. 2.]
#
# Index 492
# Source position: (x=-0.7684, y=-0.1865)
# LER=1, image positions: [-1.74015361], [-0.42244988], magnifications: [2.26483302], time delays: [0.], types: [1.]
# Lenstronomy=2, image positions: [-1.74015361  0.2033676 ], [-0.42244988  0.04936238], magnifications: [ 2.26483302 -0.26464348], time delays: [0.00000000e+00 9.82506745e+17], types: [1. 2.]

# %%
# select a few cases with good agreement to print
idx = mismatch_indices[0] if len(mismatch_indices) > 0 else 0
time_delay_seconds = tau_ls[idx, :n_img_ls[idx]][1]  # Take the second image's time delay for demonstration
time_delay_days = time_delay_seconds / (24 * 3600)
print(f"\nThe second image's time delay of 1.2e18 seconds corresponds to approximately {time_delay_days:.2e} days, which is about {time_delay_days/365.25:.2e} years. This is clearly unphysical for any realistic lensing scenario, confirming that LER's rejection of this solution is justified.")
# Out:
# The second image's time delay of 1.2e18 seconds corresponds to approximately 1.20e+13 days, which is about 3.29e+10 years. This is clearly unphysical for any realistic lensing scenario, confirming that LER's rejection of this solution is justified.

# %% [markdown]
# * Lenstronomy seems to produce an additional image with a very large time delay, which is likely unphysical and may be a numerical artifact. LER correctly identifies this as an invalid solution and rejects it, resulting in 1 images instead of 2. This highlights the importance of LER's physicality checks in ensuring that only realistic lensing solutions are accepted.

# %%
# # Section 6b: Visualization of Comparison Results
# fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# # Plot 1: Image position differences
# valid_mask = (np.isfinite(x_img_ler)) & (np.isfinite(x_img_ls))
# ax = axes[0, 0]
# ax.scatter(x_img_ls[valid_mask], x_diff, s=30, alpha=0.6)
# ax.axhline(0, color='k', linestyle='--', alpha=0.3)
# ax.axhline(0.02, color='r', linestyle=':', alpha=0.5)
# ax.axhline(-0.02, color='r', linestyle=':', alpha=0.5)
# ax.set_xlabel('Lenstronomy x position')
# ax.set_ylabel('Difference (LER - Lenstronomy)')
# ax.set_title('Image x-Position Discrepancy')
# ax.grid(True, alpha=0.3)

# # Plot 2: Magnification comparison
# valid_mag = (np.isfinite(mu_ler)) & (np.isfinite(mu_ls))
# ax = axes[0, 1]
# ax.scatter(mu_ls[valid_mag], mu_ler[valid_mag], s=30, alpha=0.6)
# lims = [min(mu_ls[valid_mag].min(), mu_ler[valid_mag].min()),
#         max(mu_ls[valid_mag].max(), mu_ler[valid_mag].max())]
# ax.plot(lims, lims, 'k--', alpha=0.5)
# ax.set_xlabel('Lenstronomy Magnification')
# ax.set_ylabel('LER Magnification')
# ax.set_title('Magnification Comparison')
# ax.grid(True, alpha=0.3)

# # Plot 3: Time delay comparison
# valid_tau = (np.isfinite(tau_ler)) & (np.isfinite(tau_ls)) & (tau_ls != 0)
# ax = axes[1, 0]
# ax.scatter(tau_ls[valid_tau], tau_ler[valid_tau], s=30, alpha=0.6)
# lims_tau = [min(tau_ls[valid_tau].min(), tau_ler[valid_tau].min()),
#             max(tau_ls[valid_tau].max(), tau_ler[valid_tau].max())]
# ax.plot(lims_tau, lims_tau, 'k--', alpha=0.5)
# ax.set_xlabel('Lenstronomy Time Delay (days)')
# ax.set_ylabel('LER Time Delay (days)')
# ax.set_title('Time Delay Comparison')
# ax.grid(True, alpha=0.3)

# # Plot 4: Relative errors distribution
# ax = axes[1, 1]
# if len(tau_diff_rel) > 0:
#     ax.hist(100*tau_diff_rel, bins=30, alpha=0.7, edgecolor='black')
#     ax.axvline(10, color='r', linestyle='--', linewidth=2, label='10% tolerance')
#     ax.set_xlabel('Relative Error (%)')
#     ax.set_ylabel('Frequency')
#     ax.set_title('Time Delay Relative Error Distribution')
#     ax.legend()
#     ax.grid(True, alpha=0.3)

# plt.tight_layout()
# plt.show()

# %%
# # Section 7: Validation Summary
# print("\n" + "=" * 80)
# print("VALIDATION SUMMARY FOR EPL+SHEAR")
# print("=" * 80)

# summary_results = {
#     'Caustic X Match': agree_x,
#     'Caustic Y Match': agree_y,
#     'Image Count Agreement': n_img_match / max(n_img_total, 1) >= 0.95,
#     'Image Position Match': (x_agree >= 0.95) and (y_agree >= 0.95) if len(x_diff) > 0 else False,
#     'Magnification Match': mu_agree >= 0.95 if len(mu_diff_rel) > 0 else False,
#     'Time Delay Match': tau_agree >= 0.90 if len(tau_diff_rel) > 0 else False,
#     'Image Type Match': (itype_match / itype_total >= 0.95) if itype_total > 0 else False,
# }

# print("\nTest Results:")
# for test_name, passed in summary_results.items():
#     status = "✓ PASS" if passed else "✗ FAIL"
#     print(f"  {test_name:<30} {status}")

# overall_pass = all(summary_results.values())
# print(f"\n{'Overall Validation':<30} {'✓ PASS' if overall_pass else '✗ FAIL'}")

# print("\nPerformance Metrics:")
# print(f"  Caustic computation time:")
# print(f"    LER:         {ler_time:.6f} seconds")
# print(f"    Lenstronomy: {ls_time:.6f} seconds")
# print(f"    Speedup:     {ls_time/ler_time:.2f}x")
# print(f"  Lens equation solving (per source):")
# print(f"    LER:         {ler_solve_time/num_samples:.6f} seconds")
# print(f"    Lenstronomy: {ls_solve_time/num_samples:.6f} seconds")
# print(f"    Speedup:     {ls_solve_time/ler_solve_time:.2f}x")

# print("\n" + "=" * 80)
