# %%
from ler.rates import LeR

ler = LeR(ver)
# Out:
# Setting multiprocessing start method to 'fork'
# ---------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from ler.rates import LeR
# ----> 3 ler = LeR()
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:499, in LeR.__init__(self, npool, z_min, z_max, event_type, size, batch_size, cosmology, snr_finder, pdet_finder, list_of_detectors, json_file_names, interpolator_directory, create_new_interpolator, ler_directory, verbose, **kwargs)
#     497 # if verbose, prevent anything from printing
#     498 if verbose:
# --> 499     initialization()
#     500     self.print_all_params()
#     501 else:
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:482, in LeR.__init__.<locals>.initialization()
#     480 def initialization():
#     481     # initialization of parent class
# --> 482     self.class_initialization(params=kwargs)
# ...
