# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import LambdaCDM
cosmo = LambdaCDM(H0=70, Om0=0.3, Ode0=0.7)
from ler.lens_galaxy_population import OpticalDepth
# Out:
# Setting multiprocessing start method to 'fork'

# %%
od_epl_choi = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min = 50., vd_max = 420., alpha = 2.32, beta = 2.67, phistar = 8.0e-3*cosmo.h**3, sigmastar = 161.0),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=False, resolution=200),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# cross-section without kneighbours: time=2min 19s
# cross-section without kneighbours: time=2min 19s
# 24, 11min 28.1s
# 160, 76min 4.1s
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_bernardi interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_bernardi_6.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x38b2c1b40>) has been set.
# optical_depth_epl_shear_numerical interpolator will be loaded from ./interpolator_pickle/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_17.pickle
# Chosen velocity dispersion sampler: velocity_dispersion_bernardi
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 2.32, 'beta': 2.67, 'phistar': 0.0027439999999999995, 'sigmastar': 161.0}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x38b24a050>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: epl_shear_galaxy

# %%
od_epl_ewoud = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=False, resolution=200),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_ewoud_8.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x3a5839090>) has been set.
# optical_depth_epl_shear_numerical interpolator will be loaded from ./interpolator_pickle/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_18.pickle
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x3a5c1bf40>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: epl_shear_galaxy

# %%
od_epl_bernardi = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=True, resolution=200),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_bernardi interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_bernardi_7.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c77c70>) has been set.
# optical_depth_epl_shear_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_8.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c77c70>)
# Computing optical depth with multiprocessing...
# 100%|███████████████████████████████████████████████████████████| 200/200 [1:51:34<00:00, 33.47s/it]
# Chosen velocity dispersion sampler: velocity_dispersion_bernardi
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x109046c20>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: epl_shear_galaxy

# %%
od_sie_ewoud = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_hemanta_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=True, resolution=200),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_ewoud_8.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c767a0>) has been set.
# optical_depth_sie_hemanta_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_sie_hemanta_numerical/optical_depth_sie_hemanta_numerical_0.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c767a0>)
# Computing optical depth with multiprocessing...
# 100%|███████████████████████████████████████████████████████████| 200/200 [1:46:06<00:00, 31.83s/it]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x352c772e0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
od_sie_ewoud2 = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=True, resolution=200),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_ewoud_8.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c77490>) has been set.
# optical_depth_sie_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_sie_numerical/optical_depth_sie_numerical_13.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x352c77490>)
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 200/200 [00:49<00:00,  4.05it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x35c885bd0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
from astropy.cosmology import Planck18

od_epl_ewoudplank18 = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(Planck18.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=Planck18,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=True, resolution=48),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_5.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_5.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_5.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_5.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_ewoud_9.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x3b63829e0>) has been set.
# optical_depth_epl_shear_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_20.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x3b63829e0>)
# Computing optical depth with multiprocessing...
# 100%|███████████████████████████████████████████████████████████████| 48/48 [27:20<00:00, 34.18s/it]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.01895458581453365, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x39382cd30>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: FlatLambdaCDM(name="Planck18", H0=67.66 km / (Mpc s), Om0=0.30966, Tcmb0=2.7255 K, Neff=3.046, m_nu=[0.   0.   0.06] eV, Ob0=0.04897)
# Chosen lens_type: epl_shear_galaxy

# %%
od_epl_ewoudlambdacdm = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=False, resolution=48),
        cross_section=dict(create_new=False, resolution=1000000),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_ewoud_8.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x35e0963b0>) has been set.
# optical_depth_epl_shear_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_21.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x35e0963b0>)
# Computing optical depth with multiprocessing...
# 100%|███████████████████████████████████████████████████████████████| 48/48 [27:02<00:00, 33.79s/it]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x35dcdfd00>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: epl_shear_galaxy

# %%
zs = np.geomspace(0.001, 10, 100)
plt.plot(zs, od_epl_ewoudplank18.strong_lensing_optical_depth(zs), label="Ewoud (Planck18)")
plt.plot(zs, od_epl_ewoudlambdacdm.strong_lensing_optical_depth(zs), label="Ewoud")
plt.plot(zs, od_epl_ewoud.strong_lensing_optical_depth(zs), label="Choi")
plt.xlabel("z")
plt.ylabel("Strong lensing optical depth")
plt.legend()
plt.show()

# %% [markdown]
# ## SIE test

# %%
# without axis rotation

od_sie_choi = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_hemanta_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min = 50., vd_max = 420., alpha = 2.32, beta = 2.67, phistar = 8.0e-3*cosmo.h**3, sigmastar = 161.0),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=True, resolution=16),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_bernardi interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_bernardi_6.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x105f6d000>) has been set.
# optical_depth_sie_hemanta_numerical interpolator will be generated at ./interpolator_pickle/optical_depth_sie_hemanta_numerical/optical_depth_sie_hemanta_numerical_1.pickle
# CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x105f6d000>)
# Computing optical depth with multiprocessing...
# 100%|███████████████████████████████████████████████████████████████| 16/16 [08:35<00:00, 32.21s/it]
# Chosen velocity dispersion sampler: velocity_dispersion_bernardi
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 2.32, 'beta': 2.67, 'phistar': 0.0027439999999999995, 'sigmastar': 161.0}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x106091b40>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
# without axis rotation

od_sie_choi2 = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min = 50., vd_max = 420., alpha = 2.32, beta = 2.67, phistar = 8.0e-3*cosmo.h**3, sigmastar = 161.0),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_pickle",
    verbose=True,
    create_new_interpolator=dict(
        optical_depth=dict(create_new=False, resolution=16),
    )
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_pickle/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_pickle/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_pickle/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_pickle/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_bernardi interpolator will be loaded from ./interpolator_pickle/velocity_dispersion/velocity_dispersion_bernardi_6.pickle
# Using pre-gererated axis ratio rayleigh pdf coefficients...
# axis_ratio_rayleigh interpolator will be loaded from ./interpolator_pickle/axis_ratio/axis_ratio_rayleigh_0.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.sampler at 0x106091ab0>) has been set.
# optical_depth_sie_numerical interpolator will be loaded from ./interpolator_pickle/optical_depth_sie_numerical/optical_depth_sie_numerical_16.pickle
# Chosen velocity dispersion sampler: velocity_dispersion_bernardi
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 2.32, 'beta': 2.67, 'phistar': 0.0027439999999999995, 'sigmastar': 161.0}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x105aeab90>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
zs = np.geomspace(0.001, 10, 100)
plt.plot(zs, od_sie_choi.strong_lensing_optical_depth(zs), label="Choi")
plt.plot(zs, od_sie_choi2.strong_lensing_optical_depth(zs), label="Choi2")
plt.xlabel("z")
plt.ylabel("Strong lensing optical depth")
plt.legend()

plt.show()

# %%
zs = np.geomspace(0.001, 10, 100)
plt.plot(zs, od_sie_choi.strong_lensing_optical_depth(zs), label="Choi")
plt.plot(zs, od_sie_choi2.strong_lensing_optical_depth(zs), label="Choi2")
plt.xlabel("z")
plt.ylabel("Strong lensing optical depth")
plt.legend()

plt.show()
