# %% [markdown]
# # Optical depth EPL+SHEAR model validation
#
# * This notebook shows example how to use the `OpticalDepth` class to create an optical depth distribution for a 'SIE' model and make comparison with various models.
#
# * You can change model or model parameters and compare the results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import LambdaCDM
cosmo = LambdaCDM(H0=70, Om0=0.3, Ode0=0.7)
from ler.lens_galaxy_population import OpticalDepth

# %%
od_sis_gengamma = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sis_galaxy",
    optical_depth_function="optical_depth_sis_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_gengamma",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min = 50., vd_max = 420., alpha = 2.32, beta = 2.67, phistar = 8.0e-3*cosmo.h**3, sigmastar = 161.0),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=False,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_gengamma interpolator will be loaded from ./interpolator_json/velocity_dispersion_gengamma/velocity_dispersion_gengamma_8.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x35326e830>) has been set.
# optical_depth_sis_numerical interpolator will be generated at ./interpolator_json/optical_depth_sis_numerical/optical_depth_sis_numerical_4.pickle
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 298/298 [01:20<00:00,  3.68it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_gengamma
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 2.32, 'beta': 2.67, 'phistar': 0.0027439999999999995, 'sigmastar': 161.0}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x3194441f0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sis_galaxy

# %%
od_sie_gengamma = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_gengamma",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min = 50., vd_max = 420., alpha = 2.32, beta = 2.67, phistar = 8.0e-3*cosmo.h**3, sigmastar = 161.0),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=False,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_gengamma interpolator will be loaded from ./interpolator_json/velocity_dispersion_gengamma/velocity_dispersion_gengamma_8.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x3532cf0a0>) has been set.
# optical_depth_sie_numerical interpolator will be generated at ./interpolator_json/optical_depth_sie_numerical/optical_depth_sie_numerical_11.pickle
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 298/298 [01:42<00:00,  2.90it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_gengamma
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 2.32, 'beta': 2.67, 'phistar': 0.0027439999999999995, 'sigmastar': 161.0}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x351e83d90>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
od_sie_bernardi = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=False,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_bernardi interpolator will be loaded from ./interpolator_json/velocity_dispersion_bernardi/velocity_dispersion_bernardi_7.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x35326feb0>) has been set.
# optical_depth_sie_numerical interpolator will be generated at ./interpolator_json/optical_depth_sie_numerical/optical_depth_sie_numerical_12.pickle
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 298/298 [01:48<00:00,  2.75it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_bernardi
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x3532cd7e0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
od_sie_ewoud = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=True,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be generated at ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be generated at ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be generated at ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be generated at ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_json/velocity_dispersion_ewoud/velocity_dispersion_ewoud_10.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x35342d1b0>) has been set.
# optical_depth_sie_numerical interpolator will be generated at ./interpolator_json/optical_depth_sie_numerical/optical_depth_sie_numerical_13.pickle
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 298/298 [02:03<00:00,  2.41it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x350981e10>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: sie_galaxy

# %%
from astropy.cosmology import Planck18

od_sie_ewoud_plack18 = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="sie_galaxy",
    optical_depth_function="optical_depth_sie_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(Planck18.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=Planck18,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=True,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be generated at ./interpolator_json/z_to_Dc/z_to_Dc_5.pickle
# Dc_to_z interpolator will be generated at ./interpolator_json/Dc_to_z/Dc_to_z_5.pickle
# angular_diameter_distance interpolator will be generated at ./interpolator_json/angular_diameter_distance/angular_diameter_distance_5.pickle
# differential_comoving_volume interpolator will be generated at ./interpolator_json/differential_comoving_volume/differential_comoving_volume_5.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_json/velocity_dispersion_ewoud/velocity_dispersion_ewoud_11.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x3532cf130>) has been set.
# optical_depth_sie_numerical interpolator will be generated at ./interpolator_json/optical_depth_sie_numerical/optical_depth_sie_numerical_14.pickle
# Computing optical depth with multiprocessing...
# 100%|█████████████████████████████████████████████████████████████| 298/298 [02:02<00:00,  2.44it/s]
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.01895458581453365, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.initialize_interpolator_optical_depth_function.<locals>.<lambda> at 0x3532ccca0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: FlatLambdaCDM(name="Planck18", H0=67.66 km / (Mpc s), Om0=0.30966, Tcmb0=2.7255 K, Neff=3.046, m_nu=[0.   0.   0.06] eV, Ob0=0.04897)
# Chosen lens_type: sie_galaxy

# %%
od_epl_ewoud = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_hemanta",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=True,
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be generated at ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be generated at ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be generated at ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be generated at ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_json/velocity_dispersion_ewoud/velocity_dispersion_ewoud_10.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x35342ef80>) has been set.
# Using pre-gererated optical depth function.
#   funtion_name: optical_depth_epl_shear_hemanta.
#   velocity_dispersion: velocity_dispersion_ewoud
#   axis_ratio: axis_ratio_rayleigh
# optical_depth_epl_shear_hemanta interpolator will be generated at ./interpolator_json/optical_depth/optical_depth_epl_shear_hemanta_1.pickle
# Chosen velocity dispersion sampler: velocity_dispersion_ewoud
# Chosen velocity dispersion sampler params: {'vd_min': 50.0, 'vd_max': 420.0, 'alpha': 0.94, 'beta': 1.85, 'phistar': 0.02099, 'sigmastar': 113.78}
# Chosen optical depth function: CPUDispatcher(<function OpticalDepth.optical_depth_epl_shear_hemanta.<locals>.<lambda> at 0x35342fac0>)
# Chosen axis ratio sampler: axis_ratio_rayleigh
# Chosen axis ratio sampler params: {'q_min': 0.2, 'q_max': 1}
# Chosen cosmology: LambdaCDM(H0=70.0 km / (Mpc s), Om0=0.3, Ode0=0.7, Tcmb0=0.0 K, Neff=3.04, m_nu=None, Ob0=None)
# Chosen lens_type: epl_shear_galaxy

# %%
sigma_gengamma = od_sie_gengamma.sample_velocity_dispersion(20000)
sigma_bernardi = od_sie_bernardi.sample_velocity_dispersion(20000)
sigma_ewoud_1p0 = od_sie_ewoud.sample_velocity_dispersion(20000, 1)
sigma_ewoud_6p0 = od_sie_ewoud.sample_velocity_dispersion(20000, 6)
sigma_ewoud_6p0_planck18 = od_sie_ewoud_plack18.sample_velocity_dispersion(20000, 6)

plt.hist(sigma_gengamma, bins=100, histtype='step', density=True, label='Choi et al. (2008)')
plt.hist(sigma_bernardi, bins=100, histtype='step', density=True, label='Bernardi et al. (2010)')
plt.hist(sigma_ewoud_1p0, bins=100, histtype='step', density=True, label='Oguri et al. (2018) z=1')
plt.hist(sigma_ewoud_6p0, bins=100, histtype='step', density=True, label='Oguri et al. (2018) z=6')
plt.hist(sigma_ewoud_6p0_planck18, bins=100, histtype='step', density=True, label='Oguri et al. (2018) z=6 Planck18')

plt.xlim(50, 350)
plt.xlabel(r'$\sigma$')
plt.ylabel('PDF')
plt.legend()
plt.show()

# %%
od_sis_gengamma.optical_depth_sis_analytic()
# Out:
# <bound method OpticalDepth.optical_depth_sis_analytic of <ler.lens_galaxy_population.optical_depth.OpticalDepth object at 0x3532efc70>>

# %%
# plot the optical depth
zs = np.linspace(0.0, 10, 100)
tau_sis_gengamma = od_sis_gengamma.strong_lensing_optical_depth(zs)
#tau_sis_gengamma = od_sis_gengamma.optical_depth_sis_analytic(zs)
tau_sie_gengamma = od_sie_gengamma.strong_lensing_optical_depth(zs)
tau_sie_bernardi = od_sie_bernardi.strong_lensing_optical_depth(zs)
tau_sie_ewoud = od_sie_ewoud.strong_lensing_optical_depth(zs)
tau_epl_ewoud = od_epl_ewoud.strong_lensing_optical_depth(zs)
tau_sie_ewoud_planck18 = od_sie_ewoud_plack18.strong_lensing_optical_depth(zs)

plt.plot(zs, tau_sis_gengamma, label=r'SIS, $\sigma$ Choi et al. (2008)')
plt.plot(zs, tau_sis_gengamma, label=r'SIE Choi et al. (2008)', linestyle='-.')
plt.plot(zs, tau_sie_bernardi, label='SIE Bernardi et al. (2010)')
plt.plot(zs, tau_sie_ewoud, label='SIE Oguri et al. (2018)')
plt.plot(zs, tau_epl_ewoud, label='EPL+SHEAR Oguri et al. (2018)')
plt.plot(zs, tau_sie_ewoud_planck18, label='SIE Oguri et al. (2018) Planck18')

plt.xlabel('z')
plt.ylabel(r'$\tau$')
plt.legend()
plt.show()

# %%
# plot the optical depth
zs = np.linspace(0.0, 2, 100)
tau_sis_gengamma = od_sis_gengamma.strong_lensing_optical_depth(zs)
tau_sie_gengamma = od_sie_gengamma.strong_lensing_optical_depth(zs)
tau_sie_bernardi = od_sie_bernardi.strong_lensing_optical_depth(zs)
tau_sie_ewoud = od_sie_ewoud.strong_lensing_optical_depth(zs)
tau_epl_ewoud = od_epl_ewoud.strong_lensing_optical_depth(zs)
tau_sie_ewoud_planck18 = od_sie_ewoud_plack18.strong_lensing_optical_depth(zs)

plt.plot(zs, tau_sis_gengamma, label='SIS Choi et al. (2008)')
plt.plot(zs, tau_sis_gengamma, label='SIE Choi et al. (2008)', linestyle='-.')
plt.plot(zs, tau_sie_bernardi, label='SIE Bernardi et al. (2010)')
plt.plot(zs, tau_sie_ewoud, label='SIE Oguri et al. (2018)')
plt.plot(zs, tau_epl_ewoud, label='EPL+SHEAR Oguri et al. (2018)')
plt.plot(zs, tau_sie_ewoud_planck18, label='SIE Oguri et al. (2018) Planck18')

plt.xlabel('z')
plt.ylabel(r'$\tau$')
plt.legend()
plt.show()

# %%
od_epl_ewoud = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_EPL_SHEAR_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=False,
)
# 16% 32mins, 8 cores
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_json/velocity_dispersion_ewoud/velocity_dispersion_ewoud_10.pickle
# optical_depth_EPL_SHEAR_numerical interpolator will be generated at ./interpolator_json/optical_depth_EPL_SHEAR_numerical/optical_depth_EPL_SHEAR_numerical_0.pickle
# Computing optical depth with multiprocessing...
#  17%|██████████▍                                                 | 52/298 [35:12<2:46:32, 40.62s/it]
# ---------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 od_epl_ewoud = OpticalDepth(
#       2     npool=8,
#       3     z_min=0.0,
#       4     z_max=10.0,
#       5     lens_type="epl_shear_galaxy",
#       6     optical_depth_function="optical_depth_EPL_SHEAR_numerical",
#       7     sampler_priors=dict(
#       8         velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
#       9         axis_ratio="axis_ratio_rayleigh",
#      10     ),
#      11     sampler_priors_params=dict(
#      12         velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
#      13         axis_ratio=dict(q_min=0.2, q_max=1),
#      14     ),
#      15     cosmology=cosmo,
#      16     directory="./interpolator_json",
#      17     verbose=True,
#      18     create_new_interpolator=False,
#      19 )
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:202, in OpticalDepth.__init__(self, npool, z_min, z_max, lens_type, optical_depth_function, sampler_priors, sampler_priors_params, cosmology, directory, create_new_interpolator, verbose)
#     199 self.sample_axis_ratio = self.sampler_priors['axis_ratio']
#     201 # setting up available optical depth function
# --> 202 self.strong_lensing_optical_depth = self.initialize_optical_depth_function(optical_depth_function)
#     204 if verbose:
#     205     self.print_all_params_opticaldepth()
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:433, in OpticalDepth.initialize_optical_depth_function(self, optical_depth_function)
#     430     tau_name = optical_depth_function
#     432 # setting up optical depth function
# --> 433 return self.initialize_interpolator_optical_depth_function(tau_name)
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:523, in OpticalDepth.initialize_interpolator_optical_depth_function(self, tau_name)
#     520         raise ValueError(f"tau_name {tau_name} not available. Choose from {self.available_optical_depth_list_and_its_params.keys()}")
#     522     # this will initialize the interpolator
# --> 523     coeff = interpolator_from_json(
#     524         param_dict_given = param_dict_given_,
#     525         directory=self.directory,
#     526         sub_directory=tau_name,
#     527         name=str(tau_name),
#     528         x = x_,
#     529         pdf_func= pdf_func_,
#     530         conditioned_y=None,
#     531         dimension=dimension_,
#     532         category="function",
#     533         create_new=self.c_n_i["optical_depth"]["create_new"],
#     534     )
#     536     optical_depth_setter = njit(lambda zs: cubic_spline_interpolator(zs, coeff[0], coeff[1]))
#     538 return optical_depth_setter
#
# File ~/phd/mypackages/ler/ler/utils/utils.py:735, in interpolator_from_json(param_dict_given, directory, sub_directory, name, x, pdf_func, y, conditioned_y, dimension, category, create_new)
#     733 if dimension==1:
#     734     if y is None:
# --> 735         y = pdf_func(x)
#     736     if category=="function":
#     737         interpolator = create_func(x, y)
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:1004, in OpticalDepth.optical_depth_multiprocessing(self, zs)
#    1002 tau_list = np.ones(len(zs))
#    1003 with Pool(processes=self.npool) as pool:
# -> 1004     for result in tqdm(
#    1005         pool.imap_unordered(self.tau_mp_routine, input_params),
#    1006         total=len(zs),
#    1007         ncols=100,
#    1008         disable=False,
#    1009     ):
#    1010         # print(result)
#    1011         (
#    1012             iter_i,
#    1013             tau,
#    1014         ) = result
#    1016         tau_list[iter_i] = tau
#
# File ~/anaconda3/envs/ler/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/envs/ler/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
od_epl_ewoud_numerical = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=dict(optical_depth=dict(create_new=True, resolution=100))
)
# Out:
# Initializing OpticalDepth class
#
# z_to_Dc interpolator will be loaded from ./interpolator_json/z_to_Dc/z_to_Dc_4.pickle
# Dc_to_z interpolator will be loaded from ./interpolator_json/Dc_to_z/Dc_to_z_4.pickle
# angular_diameter_distance interpolator will be loaded from ./interpolator_json/angular_diameter_distance/angular_diameter_distance_4.pickle
# differential_comoving_volume interpolator will be loaded from ./interpolator_json/differential_comoving_volume/differential_comoving_volume_4.pickle
# velocity_dispersion_ewoud interpolator will be loaded from ./interpolator_json/velocity_dispersion_ewoud/velocity_dispersion_ewoud_10.pickle
# axis_ratio sampler: CPUDispatcher(<function OpticalDepth.axis_ratio_rayleigh.<locals>.<lambda> at 0x35188beb0>) has been set.
# optical_depth_epl_shear_numerical interpolator will be generated at ./interpolator_json/optical_depth_epl_shear_numerical/optical_depth_epl_shear_numerical_1.pickle
# Computing optical depth with multiprocessing...
#  29%|████████████████                                        | 57/198 [5:08:28<12:43:03, 324.71s/it]
# ---------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 od_epl_ewoud_numerical = OpticalDepth(
#       2     npool=8,
#       3     z_min=0.0,
#       4     z_max=10.0,
#       5     lens_type="epl_shear_galaxy",
#       6     optical_depth_function="optical_depth_epl_shear_numerical",
#       7     sampler_priors=dict(
#       8         velocity_dispersion="velocity_dispersion_ewoud",  # zl dependent velocity dispersion
#       9         axis_ratio="axis_ratio_rayleigh",
#      10     ),
#      11     sampler_priors_params=dict(
#      12         velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
#      13         axis_ratio=dict(q_min=0.2, q_max=1),
#      14     ),
#      15     cosmology=cosmo,
#      16     directory="./interpolator_json",
#      17     verbose=True,
#      18     create_new_interpolator=dict(optical_depth=dict(create_new=True, resolution=100))
#      19 )
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:203, in OpticalDepth.__init__(self, npool, z_min, z_max, lens_type, optical_depth_function, sampler_priors, sampler_priors_params, cosmology, directory, create_new_interpolator, verbose)
#     200 print(f"axis_ratio sampler: {self.sample_axis_ratio} has been set.")
#     202 # setting up available optical depth function
# --> 203 self.strong_lensing_optical_depth = self.initialize_optical_depth_function(optical_depth_function)
#     205 if verbose:
#     206     self.print_all_params_opticaldepth()
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:448, in OpticalDepth.initialize_optical_depth_function(self, optical_depth_function)
#     445     tau_name = optical_depth_function
#     447 # setting up optical depth function
# --> 448 return self.initialize_interpolator_optical_depth_function(tau_name)
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:542, in OpticalDepth.initialize_interpolator_optical_depth_function(self, tau_name)
#     539         raise ValueError(f"tau_name {tau_name} not available. Choose from {self.available_optical_depth_list_and_its_params.keys()}")
#     541     # this will initialize the interpolator
# --> 542     coeff = interpolator_from_json(
#     543         param_dict_given = param_dict_given_,
#     544         directory=self.directory,
#     545         sub_directory=tau_name,
#     546         name=str(tau_name),
#     547         x = x_,
#     548         pdf_func= pdf_func_,
#     549         conditioned_y=None,
#     550         dimension=dimension_,
#     551         category="function",
#     552         create_new=self.c_n_i["optical_depth"]["create_new"],
#     553     )
#     555     optical_depth_setter = njit(lambda zs: cubic_spline_interpolator(zs, coeff[0], coeff[1]))
#     557 return optical_depth_setter
#
# File ~/phd/mypackages/ler/ler/utils/utils.py:735, in interpolator_from_json(param_dict_given, directory, sub_directory, name, x, pdf_func, y, conditioned_y, dimension, category, create_new)
#     733 if dimension==1:
#     734     if y is None:
# --> 735         y = pdf_func(x)
#     736     if category=="function":
#     737         interpolator = create_func(x, y)
#
# File ~/phd/mypackages/ler/ler/lens_galaxy_population/optical_depth.py:1020, in OpticalDepth.optical_depth_multiprocessing(self, zs)
#    1018 tau_list = np.ones(len(zs))
#    1019 with Pool(processes=self.npool) as pool:
# -> 1020     for result in tqdm(
#    1021         pool.imap_unordered(self.tau_mp_routine, input_params),
#    1022         total=len(zs),
#    1023         ncols=100,
#    1024         disable=False,
#    1025     ):
#    1026         # print(result)
#    1027         (
#    1028             iter_i,
#    1029             tau,
#    1030         ) = result
#    1032         tau_list[iter_i] = tau
#
# File ~/anaconda3/envs/ler/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/envs/ler/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
od_epl_ewoud_numerical = OpticalDepth(
    npool=8,
    z_min=0.0,
    z_max=10.0,
    lens_type="epl_shear_galaxy",
    optical_depth_function="optical_depth_epl_shear_numerical",
    sampler_priors=dict(
        velocity_dispersion="velocity_dispersion_bernardi",  # zl dependent velocity dispersion
        axis_ratio="axis_ratio_rayleigh",
    ),
    sampler_priors_params=dict(
        velocity_dispersion=dict(vd_min=50., vd_max=420., alpha=0.94, beta=1.85, phistar=2.099e-2*(cosmo.h/0.7)**3, sigmastar=113.78),
        axis_ratio=dict(q_min=0.2, q_max=1),
    ),
    cosmology=cosmo,
    directory="./interpolator_json",
    verbose=True,
    create_new_interpolator=dict(optical_depth=dict(create_new=True, resolution=100))
)
