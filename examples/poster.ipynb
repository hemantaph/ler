# %%
from ler import LeR  # calling the package
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# /Users/phurailatpamhemantakumar/anaconda3/envs/lal/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)

# %%
ler = LeR(nsamples=1000000, batch_size=50000)  # package initialization

ler.unlensed_cbc_statistics(json_file="./unlensed_params_BBH_1M.json",resume=True);  # unlensed param sampling

ler.unlensed_rate(gw_param="./unlensed_params_BBH_1M.json",jsonfile="./unlensed_params_detectable_BBH_1M.json");

ler.lensed_cbc_statistics(json_file="./lensed_params_BBH_1M.json", resume=True)  # lensed param sampling

ler.lensed_rate(lensed_param="./lensed_params_BBH_1M.json",jsonfile="./lensed_params_detectable_BBH_1M.json");
# Out:
# Given: IMR waveform, {self.waveform_approximant}.
# psds not given. Choosing bilby's default psds
# given psds:  {'L1': 'aLIGO_O4_high_asd.txt', 'H1': 'aLIGO_O4_high_asd.txt', 'V1': 'AdV_asd.txt'}
# Interpolator will be loaded for L1 detector from ./interpolator_pickle/L1/halfSNR_dict_0.pickle
# Interpolator will be loaded for H1 detector from ./interpolator_pickle/H1/halfSNR_dict_0.pickle
# Interpolator will be loaded for V1 detector from ./interpolator_pickle/V1/halfSNR_dict_0.pickle
# chosen batch size = 50000. If you want to change batch size, self.batch_size = new_size
# There will be 20 batche(s)
# resuming from ./unlensed_params_BBH_1M.json
# getting gw_params from json file ./unlensed_params_BBH_1M.json...
# total unlensed rate (yr^-1) (with step function): 755.1751806907038
# storing detectable unlensed params in ./unlensed_params_detectable_BBH_1M.json
# chosen batch size = 50000. If you want to change batch size, self.batch_size = new_size
# There will be 20 batche(s)
# resuming from ./lensed_params_BBH_1M.json
# Batch no. 3
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4588.04it/s]
# calculating snrs...
# Batch no. 4
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4622.35it/s]
# calculating snrs...
# Batch no. 5
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:11<00:00, 4465.33it/s]
# calculating snrs...
# Batch no. 6
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4634.59it/s]
# calculating snrs...
# Batch no. 7
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4643.30it/s]
# calculating snrs...
# Batch no. 8
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4642.46it/s]
# calculating snrs...
# Batch no. 9
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4630.13it/s]
# calculating snrs...
# Batch no. 10
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4635.39it/s]
# calculating snrs...
# Batch no. 11
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4648.44it/s]
# calculating snrs...
# Batch no. 12
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4643.13it/s]
# calculating snrs...
# Batch no. 13
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4630.12it/s]
# calculating snrs...
# Batch no. 14
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4637.42it/s]
# calculating snrs...
# Batch no. 15
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4643.66it/s]
# calculating snrs...
# Batch no. 16
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4644.45it/s]
# calculating snrs...
# Batch no. 17
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4649.20it/s]
# calculating snrs...
# Batch no. 18
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4645.61it/s]
# calculating snrs...
# Batch no. 19
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4640.62it/s]
# calculating snrs...
# Batch no. 20
# sampling lensed params...
# solving lens equations...
# 100%|███████████████████████████████████████████████████████| 50000/50000 [00:10<00:00, 4629.01it/s]
# calculating snrs...
# getting lensed_param from json file ./lensed_params_BBH_1M.json...
# total lensed rate (yr^-1) (with step function): 0.9363937687236208
# storing detectable lensed params in ./lensed_params_detectable_BBH_1M.json...

# %%
from ler import LeR
ler = LeR()
# Out:
# Given: IMR waveform, {self.waveform_approximant}.
# psds not given. Choosing bilby's default psds
# given psds:  {'L1': 'aLIGO_O4_high_asd.txt', 'H1': 'aLIGO_O4_high_asd.txt', 'V1': 'AdV_asd.txt'}
# Interpolator will be loaded for L1 detector from ./interpolator_pickle/L1/halfSNR_dict_0.pickle
# Interpolator will be loaded for H1 detector from ./interpolator_pickle/H1/halfSNR_dict_0.pickle
# Interpolator will be loaded for V1 detector from ./interpolator_pickle/V1/halfSNR_dict_0.pickle

# %%
# compute rates and their ratio
ler.rate_comparision_with_rate_calculation(
    unlened_param="./unlensed_params_BBH_1M.json",
    lensed_param="./lensed_params_BBH_1M.json",
    jsonfile_unlensed="./unlensed_params_detectable_BBH_1M.json",
    jsonfile_lensed="./lensed_params_detectable_BBH_1M.json",
);
# Out:
# getting gw_params from json file ./unlensed_params_BBH_1M.json...
# total unlensed rate (yr^-1) (with step function): 755.1751806907038
# storing detectable unlensed params in ./unlensed_params_detectable_BBH_1M.json
# getting lensed_param from json file ./lensed_params_BBH_1M.json...
# total lensed rate (yr^-1) (with step function): 0.9363937687236208
# storing detectable lensed params in ./lensed_params_detectable_BBH_1M.json...
# unlensed/lensed rate ratio =  806.4718133697831

# %%
import json
import numpy as np
from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# getting data from json
# all
with open("./unlensed_params_BBH_1M.json") as f:
    unlensed_params = json.load(f)
with open("./lensed_params_BBH_1M.json") as f:
    lensed_params = json.load(f)
# detectable
with open("./unlensed_params_detectable_BBH_1M.json") as f:
    unlensed_params_detectable = json.load(f)
with open("./lensed_params_detectable_BBH_1M.json") as f:
    lensed_params_detectable = json.load(f)

# %%
# KDE plot Detectable+Undetectable for redshift distribution
# all
kde_unlensed = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(unlensed_params['zs']).reshape(-1,1))
kde_lensed = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(lensed_params['zs']).reshape(-1,1))
kde_lenses = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(lensed_params['zl']).reshape(-1,1))
# detectable
kde_unlensed_detectable = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(unlensed_params_detectable['zs']).reshape(-1,1))
kde_lensed_detectable = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(lensed_params_detectable['zs']).reshape(-1,1))
kde_lenses_detectable = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(np.array(lensed_params_detectable['zl']).reshape(-1,1))

# %%
# plot
plt.figure(figsize=(6,4))
zs = np.linspace(0,10,100)
# all
plt.plot(zs, np.exp(kde_unlensed.score_samples(zs.reshape(-1,1))), label='unlensed sources', color='C0', linestyle='--', alpha=0.5)
plt.plot(zs, np.exp(kde_lensed.score_samples(zs.reshape(-1,1))), label='lensed sources', color='C1', linestyle='--', alpha=0.5)
plt.plot(zs, np.exp(kde_lenses.score_samples(zs.reshape(-1,1))), label='lenses', color='C2', linestyle='--', alpha=0.5)
# detectable
plt.plot(zs, np.exp(kde_unlensed_detectable.score_samples(zs.reshape(-1,1))), label='unlensed sources detectable', color='C0', linestyle='-')
plt.plot(zs, np.exp(kde_lensed_detectable.score_samples(zs.reshape(-1,1))), label='lensed sources detectable', color='C1', linestyle='-')
plt.plot(zs, np.exp(kde_lenses_detectable.score_samples(zs.reshape(-1,1))), label='lenses that cause \n detectable events', color='C2', linestyle='-')
plt.xlabel(r'$z_s$')
plt.ylabel('pdf')
leg = plt.legend(handlelength=4)
leg.get_lines()[0].set_linewidth(1.5)
leg.get_lines()[1].set_linewidth(1.5)
leg.get_lines()[2].set_linewidth(1.5)
leg.get_lines()[3].set_linewidth(1.5)
leg.get_lines()[4].set_linewidth(1.5)
leg.get_lines()[5].set_linewidth(1.5)
plt.grid(alpha=0.3)
plt.title('redshift distribution')
plt.savefig("redshift_distribution_conf1.png")

# %%
# plot
plt.figure(figsize=(4,4))
zs = np.linspace(0,5,100)
# all
plt.plot(zs, np.exp(kde_unlensed.score_samples(zs.reshape(-1,1))), label='unlensed sources', color='C0', linestyle='-', alpha=0.9)
plt.plot(zs, np.exp(kde_lensed.score_samples(zs.reshape(-1,1))), label='lensed sources', color='C1', linestyle='-', alpha=0.9)
plt.plot(zs, np.exp(kde_lenses.score_samples(zs.reshape(-1,1))), label='lenses that cause SL', color='C2', linestyle='-', alpha=0.9)
plt.xlabel(r'$z_s$')
plt.ylabel('pdf')
leg = plt.legend(handlelength=4)
leg.get_lines()[0].set_linewidth(1.5)
leg.get_lines()[1].set_linewidth(1.5)
leg.get_lines()[2].set_linewidth(1.5)
leg.get_lines()[3].set_linewidth(1.5)
leg.get_lines()[4].set_linewidth(1.5)
leg.get_lines()[5].set_linewidth(1.5)
plt.grid(alpha=0.3)
plt.title('redshift distribution')
plt.savefig("redshift_distribution_conf1.png")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> leg.get_lines()[1].set_linewidth(1.5)
#      <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a> leg.get_lines()[2].set_linewidth(1.5)
# ---> <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a> leg.get_lines()[3].set_linewidth(1.5)
#      <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a> leg.get_lines()[4].set_linewidth(1.5)
#      <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a> leg.get_lines()[5].set_linewidth(1.5)
#
# IndexError: list index out of range

# %%
mu_rel0, dt_rel0, mu_rel90, dt_rel90 = \
    ler.relative_mu_dt_lensed(lensed_param=lensed_params_detectable, snr_threshold=[8.,8.])

dmu, dt = ler.relative_mu_dt_unlensed(param=unlensed_params_detectable, size=200)

# %%
# plot
plt.figure(figsize=(6,4))
ler.mu_vs_dt_plot(x_array=dt_rel0, y_array=mu_rel0, ax=plt, colors='blue')
ler.mu_vs_dt_plot(x_array=dt, y_array=dmu, ax=plt, colors='red')
# labels
plt.xlabel(r"$log_{10}\Delta t$ (days)")
plt.ylabel(r"$\Delta log_{10}\mu$")
plt.title(r"relative magnification vs relative time delay ($\Delta \phi=0\degree$)")
# legend
custom_lines = [Line2D([0], [0], color='blue', lw=1.5),
                Line2D([0], [0], color='red', lw=1.5)]
plt.legend(custom_lines, ['lensed', 'unlensed'])
plt.savefig("mu_vs_dt_conf1.png")
plt.show()

# %%
# plot
plt.figure(figsize=(6,4))
ler.mu_vs_dt_plot(x_array=dt_rel90, y_array=mu_rel90, ax=plt, colors='blue')
ler.mu_vs_dt_plot(x_array=dt, y_array=dmu, ax=plt, colors='red')
# labels
plt.xlabel(r"$log_{10}\Delta t$ (days)")
plt.ylabel(r"$\Delta log_{10}\mu$")
plt.title(r"relative magnification vs relative time delay ($\Delta \phi=90\degree$)")
# legend
custom_lines = [Line2D([0], [0], color='blue', lw=1.5),
                Line2D([0], [0], color='red', lw=1.5)]
plt.legend(custom_lines, ['lensed', 'unlensed'])
plt.savefig("mu_vs_dt_conf1.png")
plt.show()

# %%
# plot for zs distribution
zs = unlensed_params_detectable['zs']
print(np.mean(zs))
plt.hist(zs, bins=40, density=True, alpha=0.5, label='unlensed')
plt.xlim(0,1)
plt.show()
# Out:
# 0.6470477822692138

# %%
# plot for mu distribution
mu_all = np.array(lensed_params['magnifications']).flatten()
# select only non-nan values
mu_all = np.abs(mu_all[~np.isnan(mu_all)])
# select only values less than 20
mu_all = mu_all[mu_all<20]

# for detectable
mu_detectable = np.array(lensed_params_detectable['magnifications']).flatten()
# select only non-nan values
mu_detectable = np.abs(mu_detectable[~np.isnan(mu_detectable)])
# select only values less than 20
mu_detectable = mu_detectable[mu_detectable<20]

plt.hist(mu_all, bins=40, density=True, alpha=0.5, label='lensed all', histtype='step', linewidth=1)
plt.hist(mu_detectable, bins=40, density=True, alpha=0.5, label='lensed detectable', histtype='step', linewidth=1)
plt.xlim(0,20)
# label
plt.xlabel(r"$\mu$")
plt.ylabel("pdf")
# title
plt.title("magnification distribution")
plt.legend()
plt.show()

# %%
# For merger rate density models
from ler import SourceGalaxyPopulationModel

# default model
# BBH popI/II Oguri
cbc = SourceGalaxyPopulationModel(merger_rate_density="merger_rate_density_bbh_popI_II_oguri")
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %%
z = np.geomspace(0.01, 10, 100)
dVc_dz = cbc.differential_comoving_volume(z)

plt.figure(figsize=(4,4))
plt.plot(zs, zs, color='C0', linestyle='--', alpha=0.5, label="BBH popI/II Oguri")
plt.xlabel("z")
plt.ylabel(r"$\frac{dV_c}{dz}$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb Cell 14 line 5
#       <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> dVc_dz = cbc.differential_comoving_volume(z)
#       <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize=(4,4))
# ----> <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(zs, zs, color='C0', linestyle='--', alpha=0.5, label="BBH popI/II Oguri")
#       <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> plt.xlabel("z")
#       <a href='vscode-notebook-cell:/Users/phurailatpamhemantakumar/phd/mypackages/ler/examples/poster.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> plt.ylabel(r"$\frac{dV_c}{dz}$")
#
# File ~/anaconda3/envs/lal/lib/python3.10/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~/anaconda3/envs/lal/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File ~/anaconda3/envs/lal/lib/python3.10/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2300 def add_line(self, line):
#    2301     """
#    2302     Add a `.Line2D` to the Axes; return the line.
#    2303     """
# -> 2304     _api.check_isinstance(mlines.Line2D, line=line)
#    2305     self._set_artist_props(line)
#    2306     if line.get_clip_path() is None:
#
# File ~/anaconda3/envs/lal/lib/python3.10/site-packages/matplotlib/_api/__init__.py:91, in check_isinstance(types, **kwargs)
#      89     names.remove("None")
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'line' must be an instance of matplotlib.lines.Line2D, not a matplotlib.patches.Polygon
