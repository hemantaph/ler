# %% [markdown]
# ### BBH-unlensed vs BNS-unlensed
#
# | Observing run | BBH-unlensed (Super, Sub+Super)  | BNS-unlensed (Super, Sub+Super) | Ratio BBH/BNS |
# | ---           | ---       | ---       | ---             |
# | O4 (H1, L1, V1) | 438.1, 1015.1 | 21.1, 51.6 | 20.8, 19.7 |
# | 3G (A+, ET, CE) | 100600.3, 101895.3 | 275573.2, 346692.1 | 0.36, 0.29 |
#
# ### BBH-lensed vs BNS-lensed
#
# | Observing run | BBH-lensed (Super, Sub+Super)  | BNS-lensed (Super, Sub+Super) | Ratio BBH/BNS |
# | ---           | ---       | ---       | ---             |
# | O4 (H1, L1, V1) | 1.0, 2.1 | 5.3e-2, 11.3e-2 | 18.9, 18.6 |
# | 3G (A+, ET, CE) | 107.6, 112.7 | 221.9, 475.4 | 0.48, 0.24 |
#
# ### BBH-unlensed vs BBH-lensed
#
# | Observing run | BBH-unlensed (Super, Sub+Super)  | BBH-lensed (Super, Sub+Super) | Ratio BBH-unlensed/BBH-lensed |
# | ---           | ---       | ---       | ---             |
# | O4 (H1, L1, V1) | 438.1, 1015.1 | 1.0, 2.1 | 438.1, 483.4 |
# | 3G (A+, ET, CE) | 100600.3, 101895.3 | 107.6, 112.7 | 934.9, 904.1 |
#
# ### BNS-unlensed vs BNS-lensed, GRB-unlensed vs GRB-lensed
#
# | Observing run | BNS-unlensed (Super, Sub+Super)  | BNS-lensed (Super, Sub+Super) | Ratio BNS-unlensed/BNS-lensed |
# | ---           | ---       | ---       | ---             |
# | GW O4 (H1, L1, V1) | 21.1, 51.6 | 5.3e-2, 11.3e-2 | 398.1, 456.6 |
# | GW 3G (A+, ET, CE) | 275573.2, 346692.1 | 221.9, 475.4 | 1241.8, 729.2 |
# | GRB (Fermi-GBM+Swift-BAT) | 11543.2 | 10.6 | 1087.1 |
#
# ### BNS-unlensed vs GRB-unlensed (independent)
#
# | Observing run | GRB-unlensed (Fermi-GBM+Swift-BAT) | BNS-unlensed (Super, Sub+Super)  | Ratio BNS-unlensed/GRB-unlensed |
# | ---           | ---       | ---       | ---             |
# | O4 (H1, L1, V1) | 11543.2 | 21.1, 51.6 | 547.1, 223.7 |
# | 3G (A+, ET, CE) |  11543.2 | 275573.2, 346692.1 | 0.041, 0.033 |
#
# ### BNS-lensed vs GRB-lensed (independent)
#
# | Observing run | GRB-lensed (Fermi-GBM+Swift-BAT) | BNS-lensed (Super, Sub+Super) | Ratio BNS-lensed/BNS-unlensed |
# | ---           | ---       | ---       | ---             |
# | O4 (H1, L1, V1) | 10.60 | 5.3e-2, 11.3e-2 | 200.0, 93.8 |
# | 3G (A+, ET, CE) | 10.60 | 221.9, 475.4 | 0.047, 0.022 |
#
# ### Condition 1 (EM->GW)
#
# | Event         | Unlensed  | Lensed    | Lensed:Unlensed |
# | ---           | ---       | ---       | ---             |
# | GRB           | 11543.22  | 10.60     | 1:1088.98       |
# | GW(snr>8)     | 2.39      | 4.35e-3   | 1:549.42        |
# | GW(snr>8):GRB | 1:4819.28 | 1:2439.02 | -               |
# | GW(snr>6)     | 4.93      | 1.03e-2   | 1:478.64        |
# | GW(snr>6):GRB | 1:2339.18 | 1:1030.93 | -               |
#
# ### Condition 2 (GW->EM)
#
# | Event            | Unlensed | Lensed  | Lensed:Unlensed |
# | ---              | ---      | ---     | ---             |
# | GW(snr>8)        | 21.07    | 5.26e-2 | 1:400.57        |
# | GRB (associated) | 1.91     | 3.91e-3 | 1:488.49        |
# | GRB:GW(snr>8)    | 1:11.01  | 1:13.45 | -               |

# %%
from ler.rates import LeR
from ler.utils import get_param_from_json
import numpy as np
import matplotlib.pyplot as plt

# other necessary imports
from astropy.cosmology import LambdaCDM

# %%
# Complete setup for LeR

ler = LeR(
    # LeR setup arguments
    npool=8, # number of processors to use
    z_min=0.0, # minimum redshift
    z_max=10.0, # maximum redshift
    event_type='BBH', # event type
    size=100000, # number of events to simulate
    batch_size=50000, # batch size
    cosmology=LambdaCDM(H0=70, Om0=0.3, Ode0=0.7), # cosmology
    snr_finder=None, # snr calculator from 'gwsnr' package will be used
    pdet_finder=None,  # will not be consider unless specified
    list_of_detectors=None, # list of detectors that will be considered when calculating snr or pdet for lensed events. if None, all the detectors from 'gwsnr' will be considered
    json_file_names=dict(
        ler_params="ler_params.json", # to store initialization parameters and important results
        unlensed_param="unlensed_param.json", # to store all unlensed events
        unlensed_param_detectable="unlensed_param_detectable.json", # to store only detectable unlensed events
        lensed_param="lensed_param.json", # to store all lensed events 
        lensed_param_detectable="lensed_param_detectable.json"), # to store only detectable lensed events
    interpolator_directory='./interpolator_pickle', # directory to store the interpolator pickle files. 'ler' uses interpolation to get values of various functions to speed up the calculations (relying on numba njit).
    ler_directory='./ler_data', # directory to store all the outputs
    verbose=False, # if True, will print all information at initialization

    # CBCSourceParameterDistribution class arguments
    source_priors= {
        'merger_rate_density': 'merger_rate_density_bbh_popI_II_oguri2018', 'source_frame_masses': 'binary_masses_BBH_popI_II_powerlaw_gaussian', 'zs': 'sample_source_redshift', 'geocent_time': 'sampler_uniform', 'ra': 'sampler_uniform', 'dec': 'sampler_cosine', 'phase': 'sampler_uniform', 'psi': 'sampler_uniform', 'theta_jn': 'sampler_sine'
        },
    source_priors_params= {
        'merger_rate_density': {
            'R0': 2.39e-08, 'b2': 1.6, 'b3': 2.0, 'b4': 30
            }, 
        'source_frame_masses': {
            'mminbh': 4.98, 'mmaxbh': 112.5, 'alpha': 3.78, 'mu_g': 32.27, 'sigma_g': 3.88, 'lambda_peak': 0.03, 'delta_m': 4.8, 'beta': 0.81
            }, 
        'zs': None, 
        'geocent_time': {
            'min_': 1238166018, 'max_': 1269702018
            }, 
        'ra': {
            'min_': 0.0, 'max_': 6.283185307179586
            }, 
        'dec': None, 
        'phase': {
            'min_': 0.0, 'max_': 6.283185307179586
            }, 
        'psi': {
            'min_': 0.0, 'max_': 3.141592653589793
            }, 
        'theta_jn': None
        },
    spin_zero= True, # if True, spins will be set to zero
    spin_precession= False, # if True, spins will be precessing

    # LensGalaxyParameterDistribution class arguments
    lens_type = 'epl_galaxy',
    lens_functions =  {
        'strong_lensing_condition': 'rjs_with_cross_section_SIE',
        'optical_depth': 'optical_depth_SIE_hemanta',
        'param_sampler_type': 'sample_all_routine'
        },
    lens_priors =  {
        'source_redshift_sl': 'strongly_lensed_source_redshifts', 
        'lens_redshift': 'lens_redshift_SDSS_catalogue', 
        'velocity_dispersion': 'velocity_dispersion_ewoud', 
        'axis_ratio': 'axis_ratio_rayleigh', 
        'axis_rotation_angle': 'axis_rotation_angle_uniform', 
        'shear': 'shear_norm', 
        'mass_density_spectral_index': 'mass_density_spectral_index_normal', 'source_parameters': 'sample_gw_parameters'
        },
    lens_priors_params =  {
        'source_redshift_sl': None, 
        'lens_redshift': None, 
        'velocity_dispersion': {
            'vd_min':10., 'vd_max':350.
            }, 
        'axis_ratio': {
            'q_min': 0.2, 'q_max': 1.0
            }, 
        'axis_rotation_angle': {
            'phi_min': 0.0, 'phi_max': 6.283185307179586
            }, 
        'shear': {
            'scale': 0.05
            }, 
        'mass_density_spectral_index': {
            'mean': 2.0, 'std': 0.2
            }, 
        'source_parameters': None
        },

    # ImageProperties class arguments
    n_min_images = 2,
    n_max_images = 4,
    geocent_time_min = 1238166018,
    geocent_time_max = 1269702018,
    lens_model_list = ['EPL_NUMBA', 'SHEAR'],

    # gwsnr package arguments
    mtot_min = 2.0,
    mtot_max = 184.98599853446768,
    ratio_min = 0.1,
    ratio_max = 1.0,
    mtot_resolution = 500,
    ratio_resolution = 50,
    sampling_frequency = 2048.0,
    waveform_approximant = 'IMRPhenomD',
    minimum_frequency = 20.0,
    snr_type = 'interpolation',
    psds = {'L1':'aLIGO_O4_high_asd.txt','H1':'aLIGO_O4_high_asd.txt', 'V1':'AdV_asd.txt', 'K1':'KAGRA_design_asd.txt'},
    ifos = ['L1', 'H1', 'V1'],
    interpolator_dir = './interpolator_pickle',
    gwsnr_verbose = False,
    multiprocessing_verbose = True,
    mtot_cut = True,

    # common arguments, to generate interpolator
    # create_new_interpolator = dict(
    #     redshift_distribution=dict(create_new=False, resolution=1000),
    #     z_to_luminosity_distance=dict(create_new=False, resolution=1000),
    #     velocity_dispersion=dict(create_new=False, resolution=1000),
    #     axis_ratio=dict(create_new=False, resolution=1000),
    #     optical_depth=dict(create_new=False, resolution=200),
    #     z_to_Dc=dict(create_new=False, resolution=1000),
    #     Dc_to_z=dict(create_new=False, resolution=1000),
    #     angular_diameter_distance=dict(create_new=False, resolution=1000),
    #     differential_comoving_volume=dict(create_new=False, resolution=1000),
    #     Dl_to_z=dict(create_new=False, resolution=1000),
    # )
    create_new_interpolator = False
)

# %% [markdown]
# ## Unlensed

# %%
ler.selecting_n_unlensed_detectable_events(
    size=200000,
    batch_size=200000,
    snr_threshold=6.0,
    resume=True,
    output_jsonfile='n_unlensed_param_detectable_O4_spur_sub.json',
    meta_data_file='meta_unlensed_O4_spur_sub.json',
    detectability_condition='step_function',
    trim_to_size=False,
);
# Out:
# removing ./ler_data/n_unlensed_param_detectable_O4_spur_sub.json and ./ler_data/meta_unlensed_O4_spur_sub.json if they exist
# collected number of detectable events =  0
# given detectability_condition == 'step_function'
# collected number of detectable events =  1956
# total number of events =  200000
# total rate (yr^-1): 1012.4539287969453
# given detectability_condition == 'step_function'
# collected number of detectable events =  3943
# total number of events =  400000
# total rate (yr^-1): 1020.4769532838333
# given detectability_condition == 'step_function'
# collected number of detectable events =  5907
# total number of events =  600000
# total rate (yr^-1): 1019.1829170762708
# given detectability_condition == 'step_function'
# collected number of detectable events =  7890
# total number of events =  800000
# total rate (yr^-1): 1020.9945677668584
# given detectability_condition == 'step_function'
# collected number of detectable events =  9900
# total number of events =  1000000
# total rate (yr^-1): 1024.876676389546
# given detectability_condition == 'step_function'
# collected number of detectable events =  11804
# total number of events =  1200000
# total rate (yr^-1): 1018.320226271229
# given detectability_condition == 'step_function'
# collected number of detectable events =  13719
# total number of events =  1400000
# total rate (yr^-1): 1014.4504418028991
# given detectability_condition == 'step_function'
# collected number of detectable events =  15727
# total number of events =  1600000
# total rate (yr^-1): 1017.5653718168176
# given detectability_condition == 'step_function'
# collected number of detectable events =  17731
# total number of events =  1800000
# total rate (yr^-1): 1019.7580442796319
# given detectability_condition == 'step_function'
# collected number of detectable events =  19758
# total number of events =  2000000
# total rate (yr^-1): 1022.7026955608409
# given detectability_condition == 'step_function'
# collected number of detectable events =  21715
# total number of events =  2200000
# total rate (yr^-1): 1021.818045353489
# given detectability_condition == 'step_function'
# collected number of detectable events =  23686
# total number of events =  2400000
# total rate (yr^-1): 1021.6847204108916
# given detectability_condition == 'step_function'
# collected number of detectable events =  25645
# total number of events =  2600000
# total rate (yr^-1): 1021.0941090135939
# given detectability_condition == 'step_function'
# collected number of detectable events =  27598
# total number of events =  2800000
# total rate (yr^-1): 1020.3660358946136
# given detectability_condition == 'step_function'
# collected number of detectable events =  29530
# total number of events =  3000000
# total rate (yr^-1): 1019.0103789152624
# given detectability_condition == 'step_function'
# collected number of detectable events =  31433
# total number of events =  3200000
# total rate (yr^-1): 1016.8860028078471
# given detectability_condition == 'step_function'
# collected number of detectable events =  33403
# total number of events =  3400000
# total rate (yr^-1): 1017.0515633226382
# given detectability_condition == 'step_function'
# collected number of detectable events =  35350
# total number of events =  3600000
# total rate (yr^-1): 1016.5373319408095
# given detectability_condition == 'step_function'
# collected number of detectable events =  37324
# total number of events =  3800000
# total rate (yr^-1): 1016.8127876013667
# given detectability_condition == 'step_function'
# collected number of detectable events =  39272
# total number of events =  4000000
# total rate (yr^-1): 1016.3877988679355
# given detectability_condition == 'step_function'
# collected number of detectable events =  41196
# total number of events =  4200000
# total rate (yr^-1): 1015.4117258428026
# given detectability_condition == 'step_function'
# collected number of detectable events =  43110
# total number of events =  4400000
# total rate (yr^-1): 1014.2891074185796
# given detectability_condition == 'step_function'
# collected number of detectable events =  45132
# total number of events =  4600000
# total rate (yr^-1): 1015.6946455602324
# given detectability_condition == 'step_function'
# collected number of detectable events =  47143
# total number of events =  4800000
# total rate (yr^-1): 1016.7458155520278
# given detectability_condition == 'step_function'
# collected number of detectable events =  49078
# total number of events =  5000000
# total rate (yr^-1): 1016.1393439160835
# given detectability_condition == 'step_function'
# collected number of detectable events =  50954
# total number of events =  5200000
# total rate (yr^-1): 1014.4049372329628
# given detectability_condition == 'step_function'
# collected number of detectable events =  52999
# total number of events =  5400000
# total rate (yr^-1): 1016.0388883645631
# given detectability_condition == 'step_function'
# collected number of detectable events =  54910
# total number of events =  5600000
# total rate (yr^-1): 1015.0789736751437
# given detectability_condition == 'step_function'
# collected number of detectable events =  56815
# total number of events =  5800000
# total rate (yr^-1): 1014.0781673471273
# given detectability_condition == 'step_function'
# collected number of detectable events =  58756
# total number of events =  6000000
# total rate (yr^-1): 1013.7652188206088
# given detectability_condition == 'step_function'
# collected number of detectable events =  60697
# total number of events =  6200000
# total rate (yr^-1): 1013.4724605216076
# given detectability_condition == 'step_function'
# collected number of detectable events =  62686
# total number of events =  6400000
# total rate (yr^-1): 1013.9744213408313
# given detectability_condition == 'step_function'
# collected number of detectable events =  64673
# total number of events =  6600000
# total rate (yr^-1): 1014.4145897174948
# given detectability_condition == 'step_function'
# collected number of detectable events =  66704
# total number of events =  6800000
# total rate (yr^-1): 1015.4987198735632
# given detectability_condition == 'step_function'
# collected number of detectable events =  68714
# total number of events =  7000000
# total rate (yr^-1): 1016.2103310451841
# given detectability_condition == 'step_function'
# collected number of detectable events =  70672
# total number of events =  7200000
# total rate (yr^-1): 1016.1347428984567
# given detectability_condition == 'step_function'
# collected number of detectable events =  72610
# total number of events =  7400000
# total rate (yr^-1): 1015.7834489850524
# given detectability_condition == 'step_function'
# collected number of detectable events =  74657
# total number of events =  7600000
# total rate (yr^-1): 1016.9353805052409
# given detectability_condition == 'step_function'
# collected number of detectable events =  76629
# total number of events =  7800000
# total rate (yr^-1): 1017.0328261467821
# given detectability_condition == 'step_function'
# collected number of detectable events =  78542
# total number of events =  8000000
# total rate (yr^-1): 1016.3619181437842
# given detectability_condition == 'step_function'
# collected number of detectable events =  80549
# total number of events =  8200000
# total rate (yr^-1): 1016.910463248356
# given detectability_condition == 'step_function'
# collected number of detectable events =  82460
# total number of events =  8400000
# total rate (yr^-1): 1016.249768339129
# given detectability_condition == 'step_function'
# collected number of detectable events =  84386
# total number of events =  8600000
# total rate (yr^-1): 1015.8003666174327
# given detectability_condition == 'step_function'
# collected number of detectable events =  86342
# total number of events =  8800000
# total rate (yr^-1): 1015.7243112124218
# given detectability_condition == 'step_function'
# collected number of detectable events =  88293
# total number of events =  9000000
# total rate (yr^-1): 1015.5941233272972
# given detectability_condition == 'step_function'
# collected number of detectable events =  90260
# total number of events =  9200000
# total rate (yr^-1): 1015.6496356051867
# given detectability_condition == 'step_function'
# collected number of detectable events =  92246
# total number of events =  9400000
# total rate (yr^-1): 1015.9120340665168
# given detectability_condition == 'step_function'
# collected number of detectable events =  94250
# total number of events =  9600000
# total rate (yr^-1): 1016.3576046897592
# given detectability_condition == 'step_function'
# collected number of detectable events =  96197
# total number of events =  9800000
# total rate (yr^-1): 1016.1828657869012
# given detectability_condition == 'step_function'
# collected number of detectable events =  98196
# total number of events =  10000000
# total rate (yr^-1): 1016.5534355025036
# given detectability_condition == 'step_function'
# collected number of detectable events =  100224
# total number of events =  10200000
# total rate (yr^-1): 1017.2038028764691
# given detectability_condition == 'step_function'
# collected number of detectable events =  102170
# total number of events =  10400000
# total rate (yr^-1): 1017.0129178974349
# given detectability_condition == 'step_function'
# collected number of detectable events =  104152
# total number of events =  10600000
# total rate (yr^-1): 1017.1808233211739
# given detectability_condition == 'step_function'
# collected number of detectable events =  106168
# total number of events =  10800000
# total rate (yr^-1): 1017.6684154407532
# given detectability_condition == 'step_function'
# collected number of detectable events =  108134
# total number of events =  11000000
# total rate (yr^-1): 1017.6677183168703
# given detectability_condition == 'step_function'
# collected number of detectable events =  110028
# total number of events =  11200000
# total rate (yr^-1): 1017.001541754951
# given detectability_condition == 'step_function'
# collected number of detectable events =  111964
# total number of events =  11400000
# total rate (yr^-1): 1016.7401399546263
# given detectability_condition == 'step_function'
# collected number of detectable events =  113809
# total number of events =  11600000
# total rate (yr^-1): 1015.6756327343942
# given detectability_condition == 'step_function'
# collected number of detectable events =  115785
# total number of events =  11800000
# total rate (yr^-1): 1015.7964901195307
# given detectability_condition == 'step_function'
# collected number of detectable events =  117663
# total number of events =  12000000
# total rate (yr^-1): 1015.0678819362217
# given detectability_condition == 'step_function'
# collected number of detectable events =  119657
# total number of events =  12200000
# total rate (yr^-1): 1015.3474786118886
# given detectability_condition == 'step_function'
# collected number of detectable events =  121622
# total number of events =  12400000
# total rate (yr^-1): 1015.3759460398286
# given detectability_condition == 'step_function'
# collected number of detectable events =  123623
# total number of events =  12600000
# total rate (yr^-1): 1015.6992894444832
# given detectability_condition == 'step_function'
# collected number of detectable events =  125532
# total number of events =  12800000
# total rate (yr^-1): 1015.268457548394
# given detectability_condition == 'step_function'
# collected number of detectable events =  127405
# total number of events =  13000000
# total rate (yr^-1): 1014.5642032277398
# given detectability_condition == 'step_function'
# collected number of detectable events =  129413
# total number of events =  13200000
# total rate (yr^-1): 1014.9400468442019
# given detectability_condition == 'step_function'
# collected number of detectable events =  131413
# total number of events =  13400000
# total rate (yr^-1): 1015.2428665338414
# given detectability_condition == 'step_function'
# collected number of detectable events =  133438
# total number of events =  13600000
# total rate (yr^-1): 1015.7270792043096
# given detectability_condition == 'step_function'
# collected number of detectable events =  135398
# total number of events =  13800000
# total rate (yr^-1): 1015.709648878581
# given detectability_condition == 'step_function'
# collected number of detectable events =  137261
# total number of events =  14000000
# total rate (yr^-1): 1014.9754507785387
# given detectability_condition == 'step_function'
# collected number of detectable events =  139277
# total number of events =  14200000
# total rate (yr^-1): 1015.3773570743122
# given detectability_condition == 'step_function'
# collected number of detectable events =  141229
# total number of events =  14400000
# total rate (yr^-1): 1015.307997543625
# given detectability_condition == 'step_function'
# collected number of detectable events =  143234
# total number of events =  14600000
# total rate (yr^-1): 1015.6163405699476
# given detectability_condition == 'step_function'
# collected number of detectable events =  145199
# total number of events =  14800000
# total rate (yr^-1): 1015.6365583885182
# given detectability_condition == 'step_function'
# collected number of detectable events =  147157
# total number of events =  15000000
# total rate (yr^-1): 1015.6079263801779
# given detectability_condition == 'step_function'
# collected number of detectable events =  149072
# total number of events =  15200000
# total rate (yr^-1): 1015.2871870198192
# given detectability_condition == 'step_function'
# collected number of detectable events =  150980
# total number of events =  15400000
# total rate (yr^-1): 1014.9277226898442
# given detectability_condition == 'step_function'
# collected number of detectable events =  152924
# total number of events =  15600000
# total rate (yr^-1): 1014.8163743861365
# given detectability_condition == 'step_function'
# collected number of detectable events =  154910
# total number of events =  15800000
# total rate (yr^-1): 1014.9830324734982
# given detectability_condition == 'step_function'
# collected number of detectable events =  156859
# total number of events =  16000000
# total rate (yr^-1): 1014.9061274102764
# given detectability_condition == 'step_function'
# collected number of detectable events =  158897
# total number of events =  16200000
# total rate (yr^-1): 1015.3998581386063
# given detectability_condition == 'step_function'
# collected number of detectable events =  160884
# total number of events =  16400000
# total rate (yr^-1): 1015.5596156950955
# given detectability_condition == 'step_function'
# collected number of detectable events =  162865
# total number of events =  16600000
# total rate (yr^-1): 1015.6781057574748
# given detectability_condition == 'step_function'
# collected number of detectable events =  164823
# total number of events =  16800000
# total rate (yr^-1): 1015.6520468527785
# given detectability_condition == 'step_function'
# collected number of detectable events =  166739
# total number of events =  17000000
# total rate (yr^-1): 1015.3708386483453
# given detectability_condition == 'step_function'
# collected number of detectable events =  168722
# total number of events =  17200000
# total rate (yr^-1): 1015.4994279645113
# given detectability_condition == 'step_function'
# collected number of detectable events =  170654
# total number of events =  17400000
# total rate (yr^-1): 1015.3216320247392
# given detectability_condition == 'step_function'
# collected number of detectable events =  172609
# total number of events =  17600000
# total rate (yr^-1): 1015.2831625052982
# given detectability_condition == 'step_function'
# collected number of detectable events =  174550
# total number of events =  17800000
# total rate (yr^-1): 1015.1641349664922
# given detectability_condition == 'step_function'
# collected number of detectable events =  176479
# total number of events =  18000000
# total rate (yr^-1): 1014.9787372197007
# given detectability_condition == 'step_function'
# collected number of detectable events =  178416
# total number of events =  18200000
# total rate (yr^-1): 1014.8429187185994
# given detectability_condition == 'step_function'
# collected number of detectable events =  180417
# total number of events =  18400000
# total rate (yr^-1): 1015.070132433974
# given detectability_condition == 'step_function'
# collected number of detectable events =  182335
# total number of events =  18600000
# total rate (yr^-1): 1014.8305028211571
# given detectability_condition == 'step_function'
# collected number of detectable events =  184284
# total number of events =  18800000
# total rate (yr^-1): 1014.7666743593977
# given detectability_condition == 'step_function'
# collected number of detectable events =  186250
# total number of events =  19000000
# total rate (yr^-1): 1014.7968154043218
# given detectability_condition == 'step_function'
# collected number of detectable events =  188234
# total number of events =  19200000
# total rate (yr^-1): 1014.9233812263773
# given detectability_condition == 'step_function'
# collected number of detectable events =  190219
# total number of events =  19400000
# total rate (yr^-1): 1015.052673675638
# given detectability_condition == 'step_function'
# collected number of detectable events =  192146
# total number of events =  19600000
# total rate (yr^-1): 1014.8729842380217
# given detectability_condition == 'step_function'
# collected number of detectable events =  194072
# total number of events =  19800000
# total rate (yr^-1): 1014.6916964609323
# given detectability_condition == 'step_function'
# collected number of detectable events =  195972
# total number of events =  20000000
# total rate (yr^-1): 1014.3794546737986
# given detectability_condition == 'step_function'
# collected number of detectable events =  197962
# total number of events =  20200000
# total rate (yr^-1): 1014.5346365207886
# given detectability_condition == 'step_function'
# collected number of detectable events =  199819
# total number of events =  20400000
# total rate (yr^-1): 1014.0118468978148
# given detectability_condition == 'step_function'
# collected number of detectable events =  201801
# total number of events =  20600000
# total rate (yr^-1): 1014.1273814459486
# stored detectable unlensed params in ./ler_data/n_unlensed_param_detectable_O4_spur_sub.json
# stored meta data in ./ler_data/meta_unlensed_O4_spur_sub.json

# %%
# getting data from json
meta_data= get_param_from_json("./ler_data/meta_unlensed_O4_spur_sub.json")

# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ### Sub+Super

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 1.25e7)[0]
# take average 
gw_rate_unlensed1 = np.mean(meta_data['total_rate'][idx])
print('Unlensed GW Rate (per year), SNR>6 =', gw_rate_unlensed1)
# Out:
# Unlensed GW Rate (per year), SNR>6 = 1015.107373781611

# %% [markdown]
# ### Super

# %%
unlensed_param = get_param_from_json("./ler_data/n_unlensed_param_detectable_O4_spur_sub.json")

# %%
snr = unlensed_param['optimal_snr_net']
idx = snr>8.0
snr8_vs_snr6 = np.sum(idx)/len(snr)
print('Unlensed GW Rate (per year), SNR>8 =', gw_rate_unlensed1*snr8_vs_snr6)
# Out:
# Unlensed GW Rate (per year), SNR>8 = 438.073502945441

# %% [markdown]
# ## Lensed events

# %%
ler.selecting_n_lensed_detectable_events(
    size=80000,
    batch_size=200000,
    snr_threshold=[6.0, 6.0],
    num_img=[1, 1],
    resume=True,
    detectability_condition='step_function',
    output_jsonfile='n_lensed_param_detectable_O4_spur_sub.json',
    meta_data_file='meta_lensed_O4_spur_sub.json',
    trim_to_size=False,
    nan_to_num=False,
);
# Out:
# collected number of detectable events =  60496
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:49<00:00, 4062.89it/s]
# 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:03<00:00,  1.83it/s]
# given detectability_condition == step_function
# collected number of detectable events =  62393
# total number of events =  6600000
# total rate (yr^-1): 2.146793769760623
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:48<00:00, 4081.94it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.22it/s]
# given detectability_condition == step_function
# collected number of detectable events =  64339
# total number of events =  6800000
# total rate (yr^-1): 2.148640648619495
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:49<00:00, 4026.81it/s]
# 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:03<00:00,  1.65it/s]
# given detectability_condition == step_function
# collected number of detectable events =  66239
# total number of events =  7000000
# total rate (yr^-1): 2.1488896845116505
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:48<00:00, 4162.05it/s]
# 100%|█████████████████████████████████████████████████████████████████| 2/2 [00:03<00:00,  1.65s/it]
# given detectability_condition == step_function
# collected number of detectable events =  68168
# total number of events =  7200000
# total rate (yr^-1): 2.1500395539396298
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:49<00:00, 4080.46it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.49it/s]
# given detectability_condition == step_function
# collected number of detectable events =  70020
# total number of events =  7400000
# total rate (yr^-1): 2.1487643026634924
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:48<00:00, 4096.64it/s]
# 100%|█████████████████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.18it/s]
# given detectability_condition == step_function
# collected number of detectable events =  71944
# total number of events =  7600000
# total rate (yr^-1): 2.14970755072251
# 100%|█████████████████████████████████████████████████████| 200000/200000 [00:48<00:00, 4098.58it/s]
# 100%|█████████████████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.19s/it]
# given detectability_condition == step_function
# collected number of detectable events =  73802
# total number of events =  7800000
# total rate (yr^-1): 2.1486808946203393
#  30%|████████████████                                      | 59603/200000 [00:17<00:40, 3484.12it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ler.selecting_n_lensed_detectable_events(
#       2     size=80000,
#       3     batch_size=200000,
#       4     snr_threshold=[6.0, 6.0],
#       5     num_img=[1, 1],
#       6     resume=True,
#       7     detectability_condition='step_function',
#       8     output_jsonfile='n_lensed_param_detectable_O4_spur_sub.json',
#       9     meta_data_file='meta_lensed_O4_spur_sub.json',
#      10     trim_to_size=False,
#      11     nan_to_num=False,
#      12 )
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:1983, in LeR.selecting_n_lensed_detectable_events(self, size, batch_size, snr_threshold, pdet_threshold, num_img, resume, detectability_condition, output_jsonfile, meta_data_file, trim_to_size, nan_to_num, snr_recalculation, snr_threshold_recalculation)
#    1981 with contextlib.redirect_stdout(None):
#    1982     self.dict_buffer = None  # this is used to store the sampled lensed_param in batches when running the sampling_routine
# -> 1983     lensed_param = self.lensed_sampling_routine(
#    1984         size=self.batch_size, output_jsonfile=buffer_file, resume=False
#    1985     )  # Dimensions are (size, n_max_images)
#    1987 total_events_in_this_iteration = len(lensed_param["zs"])
#    1989 # Below code ensures that the snr is recalculated for the detectable events with inner product
#    1990 # The code is use when the snr is calculated with 'ann' method of `gwsnr`
#
# File ~/phd/mypackages/ler/ler/rates/ler.py:1350, in LeR.lensed_sampling_routine(self, size, output_jsonfile, save_batch, resume)
#    1348 lensed_param_ = self.sample_lens_parameters(size=size)
#    1349 # now get (strongly lensed) image paramters along with lens parameters
# -> 1350 lensed_param_ = self.image_properties(lensed_param_)
#    1352 if len(lensed_param) == 0:  # if empty
#    1353         lensed_param = lensed_param_
#
# File ~/phd/mypackages/ler/ler/image_properties/image_properties.py:253, in ImageProperties.image_properties(self, lens_parameters)
#     249     raise ValueError("n_min_images should be greater than 1")
#     250 with Pool(processes=npool) as pool:
#     251     # call the same function with different data in parallel
#     252     # imap->retain order in the list, while map->doesn't
# --> 253     for result in tqdm(
#     254         pool.imap_unordered(solve_lens_equation_, input_arguments),
#     255         total=len(input_arguments),
#     256         ncols=100,
#     257         disable=False,
#     258     ):
#     259         # print(result)
#     260         (
#     261             x_source_i,
#     262             y_source_i,
#    (...)
#     270             iter_i,
#     271         ) = result
#     273         n_image_i = min(n_image_i, n_max_images)
#
# File ~/anaconda3/envs/ler/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/ler/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/anaconda3/envs/ler/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# getting data from json
meta_data= get_param_from_json("./ler_data/meta_lensed_O4_spur_sub.json")

# plot the rate vs sampling size
plt.figure(figsize=(6,4))
plt.plot(meta_data['events_total'], meta_data['total_rate'], 'o-')
plt.xlabel('Sampling size')
plt.ylabel('Rate (per year)')
plt.title('Rate vs Sampling size')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ### Sub+Super

# %%
# select only events after sampling size of 
idx = np.where(meta_data['events_total'] > 5.0e6)[0]
# take average 
gw_rate_lensed1 = np.mean(meta_data['total_rate'][idx])
print('Lensed GW Rate (per year), 2 or more images SNR>6 =', gw_rate_lensed1)
# Out:
# Lensed GW Rate (per year), 2 or more images SNR>6 = 2.1495015032473535

# %% [markdown]
# ### Super

# %%
snr_lensed = get_param_from_json("./ler_data/n_lensed_param_detectable_O4_spur_sub.json")['optimal_snr_net']
idx = snr_lensed>8.0
idx = np.sum(idx, axis=1)>=2
snr8_vs_snr6 = np.sum(idx)/len(snr_lensed)
print('Lensed GW Rate (per year), 2 or more images SNR>8 =', gw_rate_lensed1*snr8_vs_snr6)
# Out:
# Lensed GW Rate (per year), 2 or more images SNR>8 = 1.003452146166514
